# %% [markdown]
# ![imagen](./img/ejercicios.png)

# %% [markdown]
# # INFORMACIÓN DEL PROYECTO

# %% [markdown]
# ### TÍTULO

# %%
#Escribe el título del proyecto en Markdown
titulo = ""

# %% [markdown]
# "La paradoja del aire"

# %% [markdown]
# ### TEMA

# %%
# Describe brevemente el tema del proyecto en Markdown
tema = ""

# %% [markdown]
# Contrastar la calidad del aire en los distritos de Madrid con datos de carácter socioeconómico, ecológico y movilidad. ¿Deprecian los distritos con rentas más altas un bien público de primera necesidad, esencial para la vida humana?

# %% [markdown]
# ### HIPÓTESIS

# %% [markdown]
# Define aquí lo que será la hipótesis de tu proyecto.
# Deberás tener más de una, pero tu proyecto lo harás teniendo una principal hipótesis.

# %%
# Escribe tu hipótesis principal en Markdown
hipotesis_1 = ""

# %% [markdown]
# HIPÓTESIS PRINCIPAL DEL EDA
# - En los distritos de renta má salta de Madrid ciudad la calidad del aire es peor.

# %%
# Escribe más hipótesis si las hubiera en Markdown
# hipotesis_2 = ""
# hipotesis_3 = ""
# hipotesis_4 = ""
# hipotesis_5 = ""
# ...

# %% [markdown]
# Otras hipótesis que me surgen son las siguientes:
#
# HIPÓTESIS 2
# - A mayor densidad de población, peor calidad del aire.
#
# HIPÓTESIS 3
# - Los hábitos de movilidad de la población de un distrito pueden favorecer o perjudicar la calidad del aire.
#
# HIPÓTESIS 4
# - A mayor extensión de zonas verdes en el distrito, mejor calidad del aire.
#
# HIPÓTESIS 5
# - A mayor número de vehículos y motocicleta por habitante en el distrito, peor calidad del aire.

# %% [markdown]
# ## OBTENCIÓN DE LOS DATOS

# %% [markdown]
# ### DATASETS Y FUENTES ALTERNATIVAS DE DATOS

# %% [markdown]
# Incluye aquí una vista del dataset o datasets de los que partirás para poder evaluar tu hipótesis. <br>
# También incluye el origen de estos datos y su fuente.

# %%
import pandas as pd
# guarda en variables los datasets y su fuente
# Estaciones de medición de la calidad del aire en Madrid ciudad 
df_estaciones_aire = pd.read_csv('./data/01-informacion_estaciones_red_calidad_aire.csv', sep= ';')
fuente_1 = "https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=9e42c176313eb410VgnVCM1000000b205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default"
# Medición de la Calidad del Aire en Madrid ciudad 2022, 2023 y 2024 
df_calidad_aire = pd.read_csv('./data/02-datosdiarios202411.csv', sep=';')
fuente_2 = "https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=aecb88a7e2b73410VgnVCM2000000c205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default"
fuente_2A = 'https://airedemadrid.madrid.es/portales/calidadaire/es/Bases-de-datos-y-publicaciones/Bases-de-datos-de-calidad-del-aire/Datos-anuales/?vgnextfmt=default&vgnextchannel=b18844e815617710VgnVCM1000001d4a900aRCRD'
fuente_complementaria = 'https://airedemadrid.madrid.es/portales/calidadaire/es/Bases-de-datos-y-publicaciones/Bases-de-datos-de-calidad-del-aire/Indices-y-zonas/Zonas-de-la-ciudad-de-Madrid-a-efectos-de-Calidad-del-Aire/?vgnextfmt=default&vgnextoid=9b63d32e36bd5710VgnVCM1000001d4a900aRCRD&vgnextchannel=480285a1259d7710VgnVCM2000001f4a900aRCRD'
# Renta bruta por persona y hogar de los distritos de Madrid ciudad 2022
fuente_3 = 'https://www.ine.es/jaxiT3/Tabla.htm?t=31097'
# Población en Madrid por distrito a 1 de enero de 2023
fuente_4 = 'https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=0cccaebc07c1f710VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default'
# Superficie de parques y zonas verdes por distrito en Madrid ciudad
fuente_5 = 'https://datos.madrid.es/portal/site/egob/ menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=559b401daf436610VgnVCM1000001d4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default'
# Padrón de vehículos de Madrid por distrito
fuente_6 = 'https://www.madrid.es/portales/munimadrid/es/Inicio/El-Ayuntamiento/Estadistica/Areas-de-informacion-estadistica/Trafico-transportes-y-comunicaciones/Parque-movil/Impuesto-sobre-vehiculos-de-traccion-mecanica-IVTM-/?vgnextfmt=default&vgnextoid=cc8f23a5e6c40510VgnVCM2000000c205a0aRCRD&vgnextchannel=9f51fbc78432a210VgnVCM1000000b205a0aRCRD'
fuente_6+ = 'https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=128b5dda42c84410VgnVCM2000000c205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default'
# Encuesta de Calidad de Vida y Satisfacción con los Servicios Públicos de la Ciudad de Madrid 
fuente_7 = 'https://www.madrid.es/UnidadesDescentralizadas/Calidad/Observatorio_Ciudad/06_S_Percepcion/EncuestasCalidad/EncuestaMadrides/ficheros/2023/AA/Movilidad_Transporte.pdf'
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# Cell In[7], line 4
#       1 import pandas as pd
#       2 # guarda en variables los datasets y su fuente
#       3 # Estaciones de medición de la calidad del aire en Madrid ciudad
# ----> 4 df_estaciones_aire = pd.read_csv('./data/01-informacion_estaciones_red_calidad_aire.csv', sep= ';')
#       5 fuente_1 = "https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=9e42c176313eb410VgnVCM1000000b205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default"
#       6 # Medición de la Calidad del Aire en Madrid ciudad 2023 y 2024
#
# ...

# %% [markdown]
# Muestra mediante un head() los principales datasets con los que vas a trabajar

# %%
# Primer dataset
df_estaciones_aire
# Out:
#       CODIGO  CODIGO_CORTO              ESTACION  \
# 0   28079004             4       Plaza de España
# 1   28079008             8      Escuelas Aguirre
# 2   28079011            11         Ramón y Cajal
# 3   28079016            16          Arturo Soria
# 4   28079017            17            Villaverde
# 5   28079018            18             Farolillo
# 6   28079024            24         Casa de Campo
# 7   28079027            27        Barajas Pueblo
# 8   28079035            35      Plaza del Carmen
# 9   28079036            36             Moratalaz
# 10  28079038            38        Cuatro Caminos
# 11  28079039            39      Barrio del Pilar
# 12  28079040            40              Vallecas
# 13  28079047            47         Méndez Álvaro
# 14  28079048            48            Castellana
# 15  28079049            49     Parque del Retiro
# 16  28079050            50        Plaza Castilla
# 17  28079054            54  Ensanche de Vallecas
# ...

# %%
# Siguiente dataset...
df_calidad_aire
# Out:
#       PROVINCIA  MUNICIPIO  ESTACION  MAGNITUD PUNTO_MUESTREO   ANO  MES  \
# 0            28         79         4         1  28079004_1_38  2024    1
# 1            28         79         4         1  28079004_1_38  2024    2
# 2            28         79         4         1  28079004_1_38  2024    3
# 3            28         79         4         1  28079004_1_38  2024    4
# 4            28         79         4         1  28079004_1_38  2024    5
# ...         ...        ...       ...       ...            ...   ...  ...
# 1417         28         79        60        14  28079060_14_6  2024    7
# 1418         28         79        60        14  28079060_14_6  2024    8
# 1419         28         79        60        14  28079060_14_6  2024    9
# 1420         28         79        60        14  28079060_14_6  2024   10
# 1421         28         79        60        14  28079060_14_6  2024   11
#
#        D01 V01   D02  ...    D27  V27   D28  V28    D29  V29   D30  V30   D31  \
# ...

# %%
# Entendimiento de variables, limpieza y recopilación de datasets. Storytelling construido. Traer preguntas o dudas sobre cómo atacar el proyecto. Este es el mínimo para la vuelta de navidades. 
# Tener clara sobre que app voy a hacer la presentación y saber manejarla.

# %%
df_panel_indicadores_distritos = pd.read_csv('./data/03-panel_indicadores_distritos_barrios.csv', sep=';')
df_panel_indicadores_distritos
# Out:
#        Orden  Periodo panel            ciudad  cod_distrito distrito  \
# 0          1           2020  Ciudad de Madrid           NaN      NaN
# 1          2           2020  Ciudad de Madrid           NaN      NaN
# 2          3           2020  Ciudad de Madrid           NaN      NaN
# 3          4           2020  Ciudad de Madrid           NaN      NaN
# 4          5           2020  Ciudad de Madrid           NaN      NaN
# ...      ...            ...               ...           ...      ...
# 86367  86368           2024  Ciudad de Madrid          21.0  Barajas
# 86368  86369           2024  Ciudad de Madrid          21.0  Barajas
# 86369  86370           2024  Ciudad de Madrid          21.0  Barajas
# 86370  86371           2024  Ciudad de Madrid          21.0  Barajas
# 86371  86372           2024  Ciudad de Madrid          21.0  Barajas
#
#        cod_barrio      barrio   año fecha_indicador  \
# 0             NaN         NaN  2019      01/01/2019
# ...

# %%
fuente_6 = 'https://www.madrid.es/portales/munimadrid/es/Inicio/El-Ayuntamiento/Estadistica/Areas-de-informacion-estadistica/Trafico-transportes-y-comunicaciones/Parque-movil/Impuesto-sobre-vehiculos-de-traccion-mecanica-IVTM-/?vgnextfmt=default&vgnextoid=cc8f23a5e6c40510VgnVCM2000000c205a0aRCRD&vgnextchannel=9f51fbc78432a210VgnVCM1000000b205a0aRCRD'

# %%
# Para el xlsx del padrón de vehículos , fuente 6
import pandas as pd

# Cargar el archivo .xlsx
df = pd.read_excel('archivo.xlsx')

# Guardar el DataFrame como archivo .csv
df.to_csv('archivo.csv', index=False)  # index=False para evitar que se guarde el índice como columna
