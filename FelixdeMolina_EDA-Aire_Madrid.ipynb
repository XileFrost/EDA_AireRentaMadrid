# %% [markdown]
# ## **"La paradoja del aire en Madrid ciudad"**

# %% [markdown]
# ![imagen](./data/contaminacion-atmosferica-sobre-madrid.jpg)

# %% [markdown]
# ##### **INTRODUCCIÓN**
#
# Se asocian los países más desarrollados e industrializados con los más contaminantes a nivel mundial. Partiendo de esta premisa, en este EDA se quiere hacer una hipotética extrapolación local, a la ciudad en la que vivimos, Madrid, y **se quiere demostrar que en los distritos con rentas más altas de Madrid ciudad la calidad del aire es peor**. Asimismo, se plantean cuatros hipótesis adicionales:
# - A mayor densidad de población, peor es la calidad del aire.
# - Los hábitos de movilidad de la población de un distrito pueden favorecer o perjudicar la calidad del aire.
# - A mayor extensión de zonas verdes en el distrito, mejor calidad del aire.
# - A mayor número de habitantes por vehículo en el distrito, mejor calidad del aire.

# %% [markdown]
# Para cotejar mis hipótesis voy a valorar diferentes aspectos relacionados con la calidad del aire a partir de series de datos de diversa índole:
#
# Datos con carácter geoposicional:
# - Estaciones de medición de la calidad del aire en Madrid ciudad en 2023.
#
# Datos con caracteres medioambiental y ecológico:
# - Datos anuales de la calidad del aire en Madrid ciudad en 2023.
# - Superficie de parques y zonas verdes por distrito en Madrid ciudad en 2023.
#
# Datos con carácter socioeconómico:
# - Renta bruta por persona y hogar de los distritos de Madrid ciudad 2022.
#
# Datos con carácter demográfico:
# - Población en Madrid por distrito a 1 de enero de 2023.
#
# Datos con caracteres movilidad y transporte:
# - Padrón de vehículos en Madrid ciudad por distrito en 2024 a partir de Impuesto de vehículos de tracción mecánica 2023.
# - Medios de transporte utilizados habitualmente por distrito en 2023.

# %% [markdown]
# ##### **FUENTES DE DATOS**
#
# Antes de entrar en materia, aporto los enlaces que hicieron posible la obtención de los datos en crudo.
#
# Estaciones de medición de la calidad del aire en Madrid ciudad <br>
# 'https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=9e42c176313eb410VgnVCM1000000b205a0aRCRD&vgextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default' <br>
# Fuente: Portal de Datos abiertos del Ayuntamiento de Madrid.
#
# Datos anuales de la Calidad del Aire en Madrid ciudad 2023 <br>
# 'https://airedemadrid.madrid.es/portales/calidadaire/es/Bases-de-datos-y-publicaciones/Bases-de-datos-de-calidad-del-aire/Datos-anuales/?vgnextfmt=default&vgnextchannel=b18844e815617710VgnVCM1000001d4a900aRCRD' <br>
# Fuente: Portal de Calidad del Aire del Ayuntamiento de Madrid.
#
# Renta bruta por persona y hogar de los distritos de Madrid ciudad 2022 <br>
# 'https://www.ine.es/jaxiT3/Tabla.htm?t=31097' <br>
# Fuente: Instituto Nacional de Estadística.
#
# Distritos del municipio de Madrid <br>
# 'https://datos.comunidad.madrid/dataset/distritos_municipio_madrid' <br>
# Fuente: Datos Abiertos Comunidad de Madrid.
#
# Población en Madrid por distrito a 1 de enero de 2023 <br>
# 'https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=0cccaebc07c1f710VgnVCM2000001f4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default'<br>
# Fuente : Portal de Datos abiertos del Ayuntamiento de Madrid.
#
# Superficie de parques y zonas verdes por distrito en Madrid ciudad <br>
# 'https://datos.madrid.es/portal/site/egob/ menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=559b401daf436610VgnVCM1000001d4a900aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD&vgnextfmt=default' <br>
# Fuente : Portal de Datos abiertos del Ayuntamiento de Madrid.
#
# Padrón de vehículos de Madrid por distrito <br>
# 'https://www.madrid.es/portales/munimadrid/es/Inicio/El-Ayuntamiento/Estadistica/Areas-de-informacion-estadistica/Trafico-transportes-y-comunicaciones/Parque-movil/Impuesto-sobre-vehiculos-de-traccion-mecanica-IVTM-/?vgnextfmt=default&vgnextoid=cc8f23a5e6c40510VgnVCM2000000c205a0aRCRD&vgnextchannel=9f51fbc78432a210VgnVCM1000000b205a0aRCRD' <br>
# Fuentes : Agencia Tributaria de Madrid.
#
# Encuesta de Calidad de Vida y Satisfacción con los Servicios Públicos de la Ciudad de Madrid <br>
# 'https://www.madrid.es/UnidadesDescentralizadas/Calidad/Observatorio_Ciudad/06_S_Percepcion/EncuestasCalidad/EncuestaMadrides/ficheros/2023/AA/Movilidad_Transporte.pdf' <br>
# Fuente: Ikerfel para el Área de Acción: Movilidad y Transporte del Ayuntamiento de Madrid.

# %% [markdown]
# Tras la breve introducción, voy a mostrar los diferentes datasets por separado y estructurarlos de acuerdo a los objetos de estudio expuestos.

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ##### **DATASET 1 - Estaciones de medición de la Calidad del Aire en Madrid ciudad, año 2023**

# %%
df_dataset1= pd.read_csv('./data/01_informacion_estaciones_red_calidad_aire.csv', sep= ';')
df_dataset1
# Out:
#       CODIGO  CODIGO_CORTO              ESTACION  \
# 0   28079004             4       Plaza de España
# 1   28079008             8      Escuelas Aguirre
# 2   28079011            11         Ramón y Cajal
# 3   28079016            16          Arturo Soria
# 4   28079017            17            Villaverde
# 5   28079018            18             Farolillo
# 6   28079024            24         Casa de Campo
# 7   28079027            27        Barajas Pueblo
# 8   28079035            35      Plaza del Carmen
# 9   28079036            36             Moratalaz
# 10  28079038            38        Cuatro Caminos
# 11  28079039            39      Barrio del Pilar
# 12  28079040            40              Vallecas
# 13  28079047            47         Méndez Álvaro
# 14  28079048            48            Castellana
# 15  28079049            49     Parque del Retiro
# 16  28079050            50        Plaza Castilla
# 17  28079054            54  Ensanche de Vallecas
# 18  28079055            55         Urb. Embajada
# 19  28079056            56        Plaza Elíptica
# 20  28079057            57           Sanchinarro
# 21  28079058            58              El Pardo
# 22  28079059            59         Juan Carlos I
# 23  28079060            60           Tres Olivos
#
#                                             DIRECCION LONGITUD_ETRS89  \
# 0                                     Plaza de España    3°42'43.91"O
# 1                     Entre C/ Alcalá y C/ O’ Donell     3°40'56.22"O
# 2    Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara    3°40'38.50"O
# 3   C/ Arturo Soria  esq. C/  Vizconde de los Asilos     3°38'21.17"O
# 4                                    C/ Juan Peñalver    3°42'47.89"O
# 5                           C/ Farolillo - C/ Ervigio    3°43'54.61"O
# 6            Casa de Campo  (Terminal del Teleférico)    3°44'50.44"O
# 7                                      C/ Júpiter, 21    3°34'48.10"O
# 8                   Plaza del Carmen esq. Tres Cruces    3°42'11.40"O
# 9       Avda. Moratalaz  esq. Camino de los Vinateros    3°38'43.02"O
# 10       Avda. Pablo Iglesias esq. C/ Marqués de Lema    3°42'25.64"O
# 11         Avda. Betanzos esq. C/  Monforte de Lemos     3°42'41.53"O
# 12        C/ Arroyo del Olivar  esq. C/  Río Grande.      3°39'5.50"O
# 13  C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    3°41'12.57"O
# 14                          C/ José Gutiérrez Abascal    3°41'25.34"O
# 15              Paseo Venezuela- Palacio de Velázquez    3º 40' 57''O
# 16                             Plaza Castilla (Canal)    3°41'19.48"O
# 17                 Avda. La Gavia / Avda. Las Suertes    3°36'43.70"O
# 18                                C/ Riaño (Barajas)     3°34'50.03"O
# 19                      Plaza Elíptica - Avda. Oporto     3°43'7.54"O
# 20           C/ Princesa de Éboli esq. C/ María Tudor    3°39'37.86"O
# 21                                   Avda. La Guardia    3°46'28.62"O
# 22  Parque Juan Carlos I (frente oficinas mantenim...   3°36'32.51''O
# 23                                 Plaza Tres Olivos     3°41'23.03"O
#
#     LATITUD_ETRS89  ALTITUD COD_TIPO        NOM_TIPO NO2  ...  BTX   COD_VIA  \
# 0    40°25'25.98"N      637       UT  Urbana tráfico   X  ...  NaN    273600
# 1    40°25'17.63"N      672       UT  Urbana tráfico   X  ...    X     18900
# 2     40°27'5.29"N      709       UT  Urbana tráfico   X  ...    X    610450
# 3    40°26'24.20"N      695       UF    Urbana fondo   X  ...  NaN    798700
# 4    40°20'49.74"N      601       UF    Urbana fondo   X  ...  NaN    417200
# 5    40°23'41.22"N      625       UF    Urbana fondo   X  ...    X      1903
# 6     40°25'9.69"N      645        S       Suburbana   X  ...  NaN    905219
# 7    40°28'36.93"N      619       UF    Urbana fondo   X  ...  NaN    425700
# 8     40°25'9.15"N      660       UF    Urbana fondo   X  ...  NaN    145800
# 9    40°24'28.64"N      671       UT  Urbana tráfico   X  ...  NaN    522000
# 10   40°26'43.97"N      699       UT  Urbana tráfico   X  ...    X    554550
# 11   40°28'41.64"N      675       UT  Urbana tráfico   X  ...  NaN    514425
# 12   40°23'17.33"N      678       UF    Urbana fondo   X  ...  NaN     75500
# 13   40°23'53.17"N      600       UF    Urbana fondo   X  ...  NaN    414800
# 14   40°26'23.61"N      678       UT  Urbana tráfico   X  ...  NaN    401400
# 15   40º 24' 52''N      658       UF    Urbana fondo   X  ...  NaN    905011
# 16   40°27'56.10"N      730       UT  Urbana tráfico   X  ...  NaN    154500
# 17   40°22'22.84"N      628       UF    Urbana fondo   X  ...  NaN  31000516
# 18   40°27'44.51"N      614       UF    Urbana fondo   X  ...    X    639250
# 19    40°23'6.10"N      605       UT  Urbana tráfico   X  ...  NaN    293200
# 20   40°29'39.12"N      700       UF    Urbana fondo   X  ...  NaN  31000002
# 21    40°31'4.97"N      611        S       Suburbana   X  ...  NaN    348500
# 22  40°27'54.52''N      660        S       Suburbana   X  ...  NaN      1111
# 23    40°30'1.97"N      709       UF    Urbana fondo   X  ...  NaN      1427
#
#     VIA_CLASE VIA_PAR              VIA_NOMBRE  Fecha alta  \
# 0       PLAZA      DE                  ESPAÑA  01/12/1998
# 1       CALLE      DE                  ALCALA  01/12/1998
# 2       CALLE     DEL     PRINCIPE DE VERGARA  01/12/1998
# 3       CALLE     DEL  VIZCONDE DE LOS ASILOS  01/12/1998
# 4       CALLE      DE           JUAN PEÑALVER  01/12/1998
# 5       CALLE     DEL               FAROLILLO  31/03/2001
# 6   CARRETERA     DEL              TELEFERICO  01/12/1998
# 7       CALLE      DE                 JUPITER  31/12/2002
# 8       PLAZA     DEL                  CARMEN  01/11/1999
# 9     AVENIDA      DE               MORATALAZ  01/12/1998
# 10    AVENIDA      DE          PABLO IGLESIAS  01/11/1998
# 11    AVENIDA      DE       MONFORTE DE LEMOS  01/05/1998
# 12      CALLE     DEL       ARROYO DEL OLIVAR  30/09/1999
# 13      CALLE      DE         JUAN DE MARIANA  21/12/2009
# 14      CALLE      DE  JOSE GUTIERREZ ABASCAL  01/02/2010
# 15      PASEO      DE               VENEZUELA  01/01/2010
# 16      PLAZA      DE                CASTILLA  01/02/2010
# 17    AVENIDA      DE                LA GAVIA  11/12/2009
# 18      CALLE      DE                   RIAÑO  20/01/2010
# 19      PLAZA     NaN                ELIPTICA  18/01/2010
# 20      CALLE   DE LA       PRINCESA DE EBOLI  23/11/2009
# 21    AVENIDA   DE LA                 GUARDIA  01/12/2009
# 22        NaN     NaN                     NaN  14/12/2009
# 23      PLAZA  DE LOS             TRES OLIVOS  08/02/2010
#
#     COORDENADA_X_ETRS89 COORDENADA_Y_ETRS89  LONGITUD    LATITUD
# 0           439579,3291         4475049,263 -3.712257  40.423882
# 1           442117,2366         4474770,696 -3.682316  40.421553
# 2           442564,0457         4478088,595 -3.677349  40.451473
# 3           445786,1729         4476796,019 -3.639242  40.440046
# 4           439420,7015         4466532,455 -3.713317  40.347147
# 5           437891,6961         4471832,769 -3.731836  40.394782
# 6           436598,5637         4474571,618 -3.747345  40.419358
# 7           450835,2026         4480854,172 -3.580026  40.476918
# 8           440346,3619         4474524,357 -3.703166  40.419209
# 9            445245,513         4473237,349 -3.645310  40.407952
# 10          440033,4632         4477450,211 -3.707130  40.445544
# 11          439689,0496         4481081,619 -3.711536  40.478232
# 12          444701,6871          4471043,01 -3.651529  40.388148
# 13          441715,4303         4472170,249 -3.686814  40.398099
# 14          441449,6341          4476811,42 -3.690373  40.439890
# 15            442095,52          4473981,74 -3.682500  40.414444
# 16          441609,9474         4479662,346 -3.688745  40.465584
# 17          448033,2263         4469339,044 -3.612139  40.373012
# 18          450778,8839         4479238,863 -3.580565  40.462363
# 19          438991,9161         4470741,548 -3.718768  40.385034
# 20           444026,808         4482820,581 -3.660517  40.494201
# 21             434381,6           4485548,7 -3.774610  40.518070
# 22             448367,6          4479563,83 -3.609031  40.465144
# 23          441556,7005         4483543,994 -3.689731  40.500548
#
# [24 rows x 25 columns]

# %% [markdown]
# *El sistema de vigilancia está formado por 24 estaciones remotas automáticas que recogen la información básica para la vigilancia atmosférica. Poseen los analizadores necesarios para la medida correcta de los niveles de gases y de partículas.*
#
# *Las estaciones remotas son de varios tipos:*
#
# *- Urbanas de fondo: Representativas de la exposición de la población urbana en general.* <br>
# *- De tráfico: Situadas de tal manera que su nivel de contaminación está influido principalmente por las emisiones procedentes de una calle o carretera próxima, pero se ha de evitar que se midan microambientes muy pequeños en sus proximidades.* <br>
# *- Suburbanas: Están situadas a las afueras de la ciudad, en los lugares donde se encuentran los mayores niveles de ozono.* <br>
#
# En el siguiente [enlace](https://airedemadrid.madrid.es/portales/calidadaire/es/Bases-de-datos-y-publicaciones/Bases-de-datos-de-calidad-del-aire/Indices-y-zonas/Zonas-de-la-ciudad-de-Madrid-a-efectos-de-Calidad-del-Aire/?vgnextfmt=default&vgnextoid=9b63d32e36bd5710VgnVCM1000001d4a900aRCRD&vgnextchannel=480285a1259d7710VgnVCM2000001f4a900aRCRD) se puede consultar el mapa oficial de zonas de la ciudad de Madrid a efectos de calidad del aire. <br>
#
# **¿Qué me interesa de este dataframe?**
# Me interesan las columnas: CODIGO, CODIGO_CORTO, ESTACION, DIRECCION y NOM_TIPO. Podría no considerar la tipología de las estaciones porque, atendiendo a la propia definición de cada una de ellas, quiero considerar que las "de tráfico" están ubicadas correctamente, de modo que la propia manipulación de los datos no va a arrojar un resultado que reste credibilidad a la conclusión de mi hipótesis principal; no obstante, me viene bien esa categoría para valorar una de las hipótesis secundarias: a mayor extensión de zonas verdes en el distrito, mejor calidad del aire.

# %%
df_estaciones_info= df_dataset1[['CODIGO', 'ESTACION', 'DIRECCION', 'NOM_TIPO']]
df_estaciones_info
# Out:
#       CODIGO              ESTACION  \
# 0   28079004       Plaza de España
# 1   28079008      Escuelas Aguirre
# 2   28079011         Ramón y Cajal
# 3   28079016          Arturo Soria
# 4   28079017            Villaverde
# 5   28079018             Farolillo
# 6   28079024         Casa de Campo
# 7   28079027        Barajas Pueblo
# 8   28079035      Plaza del Carmen
# 9   28079036             Moratalaz
# 10  28079038        Cuatro Caminos
# 11  28079039      Barrio del Pilar
# 12  28079040              Vallecas
# 13  28079047         Méndez Álvaro
# 14  28079048            Castellana
# 15  28079049     Parque del Retiro
# 16  28079050        Plaza Castilla
# 17  28079054  Ensanche de Vallecas
# 18  28079055         Urb. Embajada
# 19  28079056        Plaza Elíptica
# 20  28079057           Sanchinarro
# 21  28079058              El Pardo
# 22  28079059         Juan Carlos I
# 23  28079060           Tres Olivos
#
#                                             DIRECCION        NOM_TIPO
# 0                                     Plaza de España  Urbana tráfico
# 1                     Entre C/ Alcalá y C/ O’ Donell   Urbana tráfico
# 2    Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara  Urbana tráfico
# 3   C/ Arturo Soria  esq. C/  Vizconde de los Asilos     Urbana fondo
# 4                                    C/ Juan Peñalver    Urbana fondo
# 5                           C/ Farolillo - C/ Ervigio    Urbana fondo
# 6            Casa de Campo  (Terminal del Teleférico)       Suburbana
# 7                                      C/ Júpiter, 21    Urbana fondo
# 8                   Plaza del Carmen esq. Tres Cruces    Urbana fondo
# 9       Avda. Moratalaz  esq. Camino de los Vinateros  Urbana tráfico
# 10       Avda. Pablo Iglesias esq. C/ Marqués de Lema  Urbana tráfico
# 11         Avda. Betanzos esq. C/  Monforte de Lemos   Urbana tráfico
# 12        C/ Arroyo del Olivar  esq. C/  Río Grande.     Urbana fondo
# 13  C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    Urbana fondo
# 14                          C/ José Gutiérrez Abascal  Urbana tráfico
# 15              Paseo Venezuela- Palacio de Velázquez    Urbana fondo
# 16                             Plaza Castilla (Canal)  Urbana tráfico
# 17                 Avda. La Gavia / Avda. Las Suertes    Urbana fondo
# 18                                C/ Riaño (Barajas)     Urbana fondo
# 19                      Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 20           C/ Princesa de Éboli esq. C/ María Tudor    Urbana fondo
# 21                                   Avda. La Guardia       Suburbana
# 22  Parque Juan Carlos I (frente oficinas mantenim...       Suburbana
# 23                                 Plaza Tres Olivos     Urbana fondo

# %% [markdown]
# ##### **DATASET 2 - Estaciones de medición de la Calidad del Aire en Madrid ciudad, año 2023**

# %%
df_dataset2 = pd.read_csv('./data/02_datos-aire-anuales-2023.csv', sep=';')
df_dataset2
# Out:
#                        Zona          Estación  \
# 0   Zona 01 (Interior M-30)  Barrio del Pilar
# 1   Zona 01 (Interior M-30)  Barrio del Pilar
# 2   Zona 01 (Interior M-30)        Castellana
# 3   Zona 01 (Interior M-30)        Castellana
# 4   Zona 01 (Interior M-30)        Castellana
# ..                      ...               ...
# 57       Zona 05 (Suroeste)    Plaza Elíptica
# 58       Zona 05 (Suroeste)    Plaza Elíptica
# 59       Zona 05 (Suroeste)    Plaza Elíptica
# 60       Zona 05 (Suroeste)        Villaverde
# 61       Zona 05 (Suroeste)        Villaverde
#
#                             Magnitud  Concentraciones máximas horarias  \
# 0               Dióxido de nitrógeno                               186
# 1                              Ozono                               187
# 2               Dióxido de nitrógeno                               162
# 3    Partículas en suspensión < 10µm                               117
# 4   Partículas en suspensión < 2,5µm                                62
# ..                               ...                               ...
# 57              Dióxido de nitrógeno                               195
# 58   Partículas en suspensión < 10µm                               141
# 59  Partículas en suspensión < 2,5µm                                82
# 60              Dióxido de nitrógeno                               196
# 61                             Ozono                               177
#
#     Concentraciones medias anuales
# 0                               28
# 1                               57
# 2                               29
# 3                               18
# 4                               10
# ..                             ...
# 57                              36
# 58                              24
# 59                              12
# 60                              36
# 61                              52
#
# [62 rows x 5 columns]

# %% [markdown]
# En tan sólo un vistazo veo que en los dos primeros dataframes sólo hay una columna coincidente, 'ESTACION - Estación', a partir de ella unificaré el contenido de ambos dataframes, para lo cual en la cabecera de las columnas del dataset 2 he de convertir los títulos a mayúsculas y suprimir tildes.

# %%
# Convierto a mayúsculas los títulos de las columnas y suprimo tildes.
df_dataset2.columns = df_dataset2.columns.str.upper()
df_dataset2.columns = df_dataset2.columns.str.replace('ESTACIÓN','ESTACION')
df_dataset2.columns = df_dataset2.columns.str.replace('CONCENTRACIONES MÁXIMAS HORARIAS', 'CONCENTRACIONES MAXIMAS HORARIAS')
df_dataset2
# Out:
#                        ZONA          ESTACION  \
# 0   Zona 01 (Interior M-30)  Barrio del Pilar
# 1   Zona 01 (Interior M-30)  Barrio del Pilar
# 2   Zona 01 (Interior M-30)        Castellana
# 3   Zona 01 (Interior M-30)        Castellana
# 4   Zona 01 (Interior M-30)        Castellana
# ..                      ...               ...
# 57       Zona 05 (Suroeste)    Plaza Elíptica
# 58       Zona 05 (Suroeste)    Plaza Elíptica
# 59       Zona 05 (Suroeste)    Plaza Elíptica
# 60       Zona 05 (Suroeste)        Villaverde
# 61       Zona 05 (Suroeste)        Villaverde
#
#                             MAGNITUD  CONCENTRACIONES MAXIMAS HORARIAS  \
# 0               Dióxido de nitrógeno                               186
# 1                              Ozono                               187
# 2               Dióxido de nitrógeno                               162
# 3    Partículas en suspensión < 10µm                               117
# 4   Partículas en suspensión < 2,5µm                                62
# ..                               ...                               ...
# 57              Dióxido de nitrógeno                               195
# 58   Partículas en suspensión < 10µm                               141
# 59  Partículas en suspensión < 2,5µm                                82
# 60              Dióxido de nitrógeno                               196
# 61                             Ozono                               177
#
#     CONCENTRACIONES MEDIAS ANUALES
# 0                               28
# 1                               57
# 2                               29
# 3                               18
# 4                               10
# ..                             ...
# 57                              36
# 58                              24
# 59                              12
# 60                              36
# 61                              52
#
# [62 rows x 5 columns]

# %%
# Unifico los dos dataframes en un nuevo dataframe a partir de la columna 'ESTACION'
df_aire = pd.merge(df_estaciones_info, df_dataset2, on='ESTACION', how='inner') 
df_aire
# Out:
#       CODIGO          ESTACION  \
# 0   28079004   Plaza de España
# 1   28079004   Plaza de España
# 2   28079008  Escuelas Aguirre
# 3   28079008  Escuelas Aguirre
# 4   28079008  Escuelas Aguirre
# ..       ...               ...
# 57  28079059     Juan Carlos I
# 58  28079059     Juan Carlos I
# 59  28079060       Tres Olivos
# 60  28079060       Tres Olivos
# 61  28079060       Tres Olivos
#
#                                             DIRECCION        NOM_TIPO  \
# 0                                     Plaza de España  Urbana tráfico
# 1                                     Plaza de España  Urbana tráfico
# 2                     Entre C/ Alcalá y C/ O’ Donell   Urbana tráfico
# 3                     Entre C/ Alcalá y C/ O’ Donell   Urbana tráfico
# 4                     Entre C/ Alcalá y C/ O’ Donell   Urbana tráfico
# ..                                                ...             ...
# 57  Parque Juan Carlos I (frente oficinas mantenim...       Suburbana
# 58  Parque Juan Carlos I (frente oficinas mantenim...       Suburbana
# 59                                 Plaza Tres Olivos     Urbana fondo
# 60                                 Plaza Tres Olivos     Urbana fondo
# 61                                 Plaza Tres Olivos     Urbana fondo
#
#                        ZONA                         MAGNITUD  \
# 0   Zona 01 (Interior M-30)                Dióxido de azufre
# 1   Zona 01 (Interior M-30)             Dióxido de nitrógeno
# 2   Zona 01 (Interior M-30)                Dióxido de azufre
# 3   Zona 01 (Interior M-30)             Dióxido de nitrógeno
# 4   Zona 01 (Interior M-30)                            Ozono
# ..                      ...                              ...
# 57        Zona 03 (Noreste)             Dióxido de nitrógeno
# 58        Zona 03 (Noreste)                            Ozono
# 59        Zona 03 (Noreste)             Dióxido de nitrógeno
# 60        Zona 03 (Noreste)                            Ozono
# 61        Zona 03 (Noreste)  Partículas en suspensión < 10µm
#
#     CONCENTRACIONES MAXIMAS HORARIAS  CONCENTRACIONES MEDIAS ANUALES
# 0                                 11                               2
# 1                                156                              28
# 2                                 11                               3
# 3                                175                              33
# 4                                197                              53
# ..                               ...                             ...
# 57                               137                              22
# 58                               227                              62
# 59                               135                              21
# 60                               194                              58
# 61                               153                              18
#
# [62 rows x 8 columns]

# %%
# Reordeno las columnas, para que ZONA esté primero y ESTACION en segundo lugar.
cols = ['ZONA', 'ESTACION'] + [col for col in df_aire.columns if col not in ['ZONA', 'ESTACION']]
df_aire = df_aire[cols]
# Ordeno el dataframe por 'ZONA' y luego por 'ESTACION'.
df_aire = df_aire.sort_values(by=['ZONA', 'ESTACION'], ascending=[True, True])
df_aire = df_aire.reset_index(drop=True)
df_aire
# Out:
#                        ZONA          ESTACION    CODIGO  \
# 0   Zona 01 (Interior M-30)  Barrio del Pilar  28079039
# 1   Zona 01 (Interior M-30)  Barrio del Pilar  28079039
# 2   Zona 01 (Interior M-30)        Castellana  28079048
# 3   Zona 01 (Interior M-30)        Castellana  28079048
# 4   Zona 01 (Interior M-30)        Castellana  28079048
# ..                      ...               ...       ...
# 57       Zona 05 (Suroeste)    Plaza Elíptica  28079056
# 58       Zona 05 (Suroeste)    Plaza Elíptica  28079056
# 59       Zona 05 (Suroeste)    Plaza Elíptica  28079056
# 60       Zona 05 (Suroeste)        Villaverde  28079017
# 61       Zona 05 (Suroeste)        Villaverde  28079017
#
#                                      DIRECCION        NOM_TIPO  \
# 0   Avda. Betanzos esq. C/  Monforte de Lemos   Urbana tráfico
# 1   Avda. Betanzos esq. C/  Monforte de Lemos   Urbana tráfico
# 2                    C/ José Gutiérrez Abascal  Urbana tráfico
# 3                    C/ José Gutiérrez Abascal  Urbana tráfico
# 4                    C/ José Gutiérrez Abascal  Urbana tráfico
# ..                                         ...             ...
# 57               Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 58               Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 59               Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 60                            C/ Juan Peñalver    Urbana fondo
# 61                            C/ Juan Peñalver    Urbana fondo
#
#                             MAGNITUD  CONCENTRACIONES MAXIMAS HORARIAS  \
# 0               Dióxido de nitrógeno                               186
# 1                              Ozono                               187
# 2               Dióxido de nitrógeno                               162
# 3    Partículas en suspensión < 10µm                               117
# 4   Partículas en suspensión < 2,5µm                                62
# ..                               ...                               ...
# 57              Dióxido de nitrógeno                               195
# 58   Partículas en suspensión < 10µm                               141
# 59  Partículas en suspensión < 2,5µm                                82
# 60              Dióxido de nitrógeno                               196
# 61                             Ozono                               177
#
#     CONCENTRACIONES MEDIAS ANUALES
# 0                               28
# 1                               57
# 2                               29
# 3                               18
# 4                               10
# ..                             ...
# 57                              36
# 58                              24
# 59                              12
# 60                              36
# 61                              52
#
# [62 rows x 8 columns]

# %% [markdown]
# El actual [protocolo de actuación del Ayuntamiento de Madrid para episodios de alta contaminación](https://www.madrid.es/portales/munimadrid/es/Inicio/Medidas-especiales-de-movilidad/Protocolo-de-contaminacion/Protocolo-de-actuacion-para-episodios-de-contaminacion-por-dioxido-de-nitrogeno/?vgnextfmt=default&vgnextoid=fd8718cea863c410VgnVCM1000000b205a0aRCRD&vgnextchannel=00b3cf7588c97610VgnVCM2000001f4a900aRCRD), vigente desde el 10 de diciembre de 2018, se activa en función de las concentraciones de 'Dióxido de nitrógeno' (NO2). Esto podría explicar que dicho dato sea el único valor común medido por las 24 Estaciones de Medición de Calidad del Aire de la ciudad Madrid, por ello haré un último filtrado en el dataframe, quedándome sólo con las filas en las que esté presente la 'MAGNITUD' 'Dióxido de nitrógeno'.

# %%
df_aire = df_aire[df_aire['MAGNITUD'] == 'Dióxido de nitrógeno']
df_aire = df_aire.reset_index(drop=True)
df_aire
# Out:
#                        ZONA              ESTACION    CODIGO  \
# 0   Zona 01 (Interior M-30)      Barrio del Pilar  28079039
# 1   Zona 01 (Interior M-30)            Castellana  28079048
# 2   Zona 01 (Interior M-30)        Cuatro Caminos  28079038
# 3   Zona 01 (Interior M-30)      Escuelas Aguirre  28079008
# 4   Zona 01 (Interior M-30)         Méndez Álvaro  28079047
# 5   Zona 01 (Interior M-30)     Parque del Retiro  28079049
# 6   Zona 01 (Interior M-30)        Plaza Castilla  28079050
# 7   Zona 01 (Interior M-30)       Plaza de España  28079004
# 8   Zona 01 (Interior M-30)      Plaza del Carmen  28079035
# 9   Zona 01 (Interior M-30)         Ramón y Cajal  28079011
# 10        Zona 02 (Sureste)  Ensanche de Vallecas  28079054
# 11        Zona 02 (Sureste)             Moratalaz  28079036
# 12        Zona 02 (Sureste)              Vallecas  28079040
# 13        Zona 03 (Noreste)          Arturo Soria  28079016
# 14        Zona 03 (Noreste)        Barajas Pueblo  28079027
# 15        Zona 03 (Noreste)         Juan Carlos I  28079059
# 16        Zona 03 (Noreste)           Sanchinarro  28079057
# 17        Zona 03 (Noreste)           Tres Olivos  28079060
# 18        Zona 03 (Noreste)         Urb. Embajada  28079055
# 19       Zona 04 (Noroeste)         Casa de Campo  28079024
# 20       Zona 04 (Noroeste)              El Pardo  28079058
# 21       Zona 05 (Suroeste)             Farolillo  28079018
# 22       Zona 05 (Suroeste)        Plaza Elíptica  28079056
# 23       Zona 05 (Suroeste)            Villaverde  28079017
#
#                                             DIRECCION        NOM_TIPO  \
# 0          Avda. Betanzos esq. C/  Monforte de Lemos   Urbana tráfico
# 1                           C/ José Gutiérrez Abascal  Urbana tráfico
# 2        Avda. Pablo Iglesias esq. C/ Marqués de Lema  Urbana tráfico
# 3                     Entre C/ Alcalá y C/ O’ Donell   Urbana tráfico
# 4   C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    Urbana fondo
# 5               Paseo Venezuela- Palacio de Velázquez    Urbana fondo
# 6                              Plaza Castilla (Canal)  Urbana tráfico
# 7                                     Plaza de España  Urbana tráfico
# 8                   Plaza del Carmen esq. Tres Cruces    Urbana fondo
# 9    Avda. Ramón y Cajal  esq. C/ Príncipe de Vergara  Urbana tráfico
# 10                 Avda. La Gavia / Avda. Las Suertes    Urbana fondo
# 11      Avda. Moratalaz  esq. Camino de los Vinateros  Urbana tráfico
# 12        C/ Arroyo del Olivar  esq. C/  Río Grande.     Urbana fondo
# 13  C/ Arturo Soria  esq. C/  Vizconde de los Asilos     Urbana fondo
# 14                                     C/ Júpiter, 21    Urbana fondo
# 15  Parque Juan Carlos I (frente oficinas mantenim...       Suburbana
# 16           C/ Princesa de Éboli esq. C/ María Tudor    Urbana fondo
# 17                                 Plaza Tres Olivos     Urbana fondo
# 18                                C/ Riaño (Barajas)     Urbana fondo
# 19           Casa de Campo  (Terminal del Teleférico)       Suburbana
# 20                                   Avda. La Guardia       Suburbana
# 21                          C/ Farolillo - C/ Ervigio    Urbana fondo
# 22                      Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 23                                   C/ Juan Peñalver    Urbana fondo
#
#                 MAGNITUD  CONCENTRACIONES MAXIMAS HORARIAS  \
# 0   Dióxido de nitrógeno                               186
# 1   Dióxido de nitrógeno                               162
# 2   Dióxido de nitrógeno                               167
# 3   Dióxido de nitrógeno                               175
# 4   Dióxido de nitrógeno                               140
# 5   Dióxido de nitrógeno                               131
# 6   Dióxido de nitrógeno                               166
# 7   Dióxido de nitrógeno                               156
# 8   Dióxido de nitrógeno                               130
# 9   Dióxido de nitrógeno                               183
# 10  Dióxido de nitrógeno                               194
# 11  Dióxido de nitrógeno                               139
# 12  Dióxido de nitrógeno                               147
# 13  Dióxido de nitrógeno                               177
# 14  Dióxido de nitrógeno                               163
# 15  Dióxido de nitrógeno                               137
# 16  Dióxido de nitrógeno                               186
# 17  Dióxido de nitrógeno                               135
# 18  Dióxido de nitrógeno                               171
# 19  Dióxido de nitrógeno                                98
# 20  Dióxido de nitrógeno                                86
# 21  Dióxido de nitrógeno                               149
# 22  Dióxido de nitrógeno                               195
# 23  Dióxido de nitrógeno                               196
#
#     CONCENTRACIONES MEDIAS ANUALES
# 0                               28
# 1                               29
# 2                               29
# 3                               33
# 4                               28
# 5                               20
# 6                               30
# 7                               28
# 8                               31
# 9                               30
# 10                              30
# 11                              29
# 12                              30
# 13                              27
# 14                              34
# 15                              22
# 16                              24
# 17                              21
# 18                              29
# 19                              16
# 20                              13
# 21                              27
# 22                              36
# 23                              36

# %%
# Me quedo sólo con las columnas 'ESTACION', 'CONCENTRACIONES MAXIMAS HORARIAS' y 'CONCENTRACIONES MEDIAS ANUALES'.
df_no2 = df_aire[['ESTACION', 'CONCENTRACIONES MAXIMAS HORARIAS']]
df_no2
# Out:
#                 ESTACION  CONCENTRACIONES MAXIMAS HORARIAS
# 0       Barrio del Pilar                               186
# 1             Castellana                               162
# 2         Cuatro Caminos                               167
# 3       Escuelas Aguirre                               175
# 4          Méndez Álvaro                               140
# 5      Parque del Retiro                               131
# 6         Plaza Castilla                               166
# 7        Plaza de España                               156
# 8       Plaza del Carmen                               130
# 9          Ramón y Cajal                               183
# 10  Ensanche de Vallecas                               194
# 11             Moratalaz                               139
# 12              Vallecas                               147
# 13          Arturo Soria                               177
# 14        Barajas Pueblo                               163
# 15         Juan Carlos I                               137
# 16           Sanchinarro                               186
# 17           Tres Olivos                               135
# 18         Urb. Embajada                               171
# 19         Casa de Campo                                98
# 20              El Pardo                                86
# 21             Farolillo                               149
# 22        Plaza Elíptica                               195
# 23            Villaverde                               196

# %% [markdown]
# ##### **DATASET 3 - Renta bruta por persona y hogar de los distritos de Madrid ciudad, año 2022**

# %%
df_dataset3 = pd.read_csv('./data/03_renta_bruta_media_persona_y_hogar.csv', sep=';')
df_dataset3
# Out:
#       Municipios                   Distritos  Secciones  \
# 0   28079 Madrid                         NaN        NaN
# 1   28079 Madrid                         NaN        NaN
# 2   28079 Madrid  2807901 Madrid distrito 01        NaN
# 3   28079 Madrid  2807901 Madrid distrito 01        NaN
# 4   28079 Madrid  2807902 Madrid distrito 02        NaN
# 5   28079 Madrid  2807902 Madrid distrito 02        NaN
# 6   28079 Madrid  2807903 Madrid distrito 03        NaN
# 7   28079 Madrid  2807903 Madrid distrito 03        NaN
# 8   28079 Madrid  2807904 Madrid distrito 04        NaN
# 9   28079 Madrid  2807904 Madrid distrito 04        NaN
# 10  28079 Madrid  2807905 Madrid distrito 05        NaN
# 11  28079 Madrid  2807905 Madrid distrito 05        NaN
# 12  28079 Madrid  2807906 Madrid distrito 06        NaN
# 13  28079 Madrid  2807906 Madrid distrito 06        NaN
# 14  28079 Madrid  2807907 Madrid distrito 07        NaN
# 15  28079 Madrid  2807907 Madrid distrito 07        NaN
# 16  28079 Madrid  2807908 Madrid distrito 08        NaN
# 17  28079 Madrid  2807908 Madrid distrito 08        NaN
# 18  28079 Madrid  2807909 Madrid distrito 09        NaN
# 19  28079 Madrid  2807909 Madrid distrito 09        NaN
# 20  28079 Madrid  2807910 Madrid distrito 10        NaN
# 21  28079 Madrid  2807910 Madrid distrito 10        NaN
# 22  28079 Madrid  2807911 Madrid distrito 11        NaN
# 23  28079 Madrid  2807911 Madrid distrito 11        NaN
# 24  28079 Madrid  2807912 Madrid distrito 12        NaN
# 25  28079 Madrid  2807912 Madrid distrito 12        NaN
# 26  28079 Madrid  2807913 Madrid distrito 13        NaN
# 27  28079 Madrid  2807913 Madrid distrito 13        NaN
# 28  28079 Madrid  2807914 Madrid distrito 14        NaN
# 29  28079 Madrid  2807914 Madrid distrito 14        NaN
# 30  28079 Madrid  2807915 Madrid distrito 15        NaN
# 31  28079 Madrid  2807915 Madrid distrito 15        NaN
# 32  28079 Madrid  2807916 Madrid distrito 16        NaN
# 33  28079 Madrid  2807916 Madrid distrito 16        NaN
# 34  28079 Madrid  2807917 Madrid distrito 17        NaN
# 35  28079 Madrid  2807917 Madrid distrito 17        NaN
# 36  28079 Madrid  2807918 Madrid distrito 18        NaN
# 37  28079 Madrid  2807918 Madrid distrito 18        NaN
# 38  28079 Madrid  2807919 Madrid distrito 19        NaN
# 39  28079 Madrid  2807919 Madrid distrito 19        NaN
# 40  28079 Madrid  2807920 Madrid distrito 20        NaN
# 41  28079 Madrid  2807920 Madrid distrito 20        NaN
# 42  28079 Madrid  2807921 Madrid distrito 21        NaN
# 43  28079 Madrid  2807921 Madrid distrito 21        NaN
#
#    Indicadores de renta media y mediana  Periodo    Total
# 0         Renta bruta media por persona     2022   23.984
# 1           Renta bruta media por hogar     2022   60.049
# 2         Renta bruta media por persona     2022   27.030
# 3           Renta bruta media por hogar     2022   53.908
# 4         Renta bruta media por persona     2022   27.431
# 5           Renta bruta media por hogar     2022   63.160
# 6         Renta bruta media por persona     2022   33.396
# 7           Renta bruta media por hogar     2022   79.868
# 8         Renta bruta media por persona     2022   38.751
# 9           Renta bruta media por hogar     2022   89.407
# 10        Renta bruta media por persona     2022   42.678
# 11          Renta bruta media por hogar     2022  104.706
# 12        Renta bruta media por persona     2022   22.890
# 13          Renta bruta media por hogar     2022   53.816
# 14        Renta bruta media por persona     2022   36.934
# 15          Renta bruta media por hogar     2022   81.889
# 16        Renta bruta media por persona     2022   28.798
# 17          Renta bruta media por hogar     2022   76.386
# 18        Renta bruta media por persona     2022   36.592
# 19          Renta bruta media por hogar     2022   93.541
# 20        Renta bruta media por persona     2022   17.267
# 21          Renta bruta media por hogar     2022   42.843
# 22        Renta bruta media por persona     2022   15.239
# 23          Renta bruta media por hogar     2022   40.339
# 24        Renta bruta media por persona     2022   13.481
# 25          Renta bruta media por hogar     2022   37.737
# 26        Renta bruta media por persona     2022   13.354
# 27          Renta bruta media por hogar     2022   35.380
# 28        Renta bruta media por persona     2022   20.091
# 29          Renta bruta media por hogar     2022   49.289
# 30        Renta bruta media por persona     2022   22.440
# 31          Renta bruta media por hogar     2022   55.112
# 32        Renta bruta media por persona     2022   29.047
# 33          Renta bruta media por hogar     2022   76.741
# 34        Renta bruta media por persona     2022   13.604
# 35          Renta bruta media por hogar     2022   38.269
# 36        Renta bruta media por persona     2022   17.346
# 37          Renta bruta media por hogar     2022   44.960
# 38        Renta bruta media por persona     2022   18.214
# 39          Renta bruta media por hogar     2022   48.513
# 40        Renta bruta media por persona     2022   19.768
# 41          Renta bruta media por hogar     2022   51.558
# 42        Renta bruta media por persona     2022   27.125
# 43          Renta bruta media por hogar     2022   70.909

# %%
# Elimino las columnas 'Municipios' y 'Secciones'.
df_dataset3= df_dataset3.drop(['Municipios','Secciones'], axis = 1 )
df_dataset3
# Out:
#                      Distritos Indicadores de renta media y mediana  Periodo  \
# 0                          NaN        Renta bruta media por persona     2022
# 1                          NaN          Renta bruta media por hogar     2022
# 2   2807901 Madrid distrito 01        Renta bruta media por persona     2022
# 3   2807901 Madrid distrito 01          Renta bruta media por hogar     2022
# 4   2807902 Madrid distrito 02        Renta bruta media por persona     2022
# 5   2807902 Madrid distrito 02          Renta bruta media por hogar     2022
# 6   2807903 Madrid distrito 03        Renta bruta media por persona     2022
# 7   2807903 Madrid distrito 03          Renta bruta media por hogar     2022
# 8   2807904 Madrid distrito 04        Renta bruta media por persona     2022
# 9   2807904 Madrid distrito 04          Renta bruta media por hogar     2022
# 10  2807905 Madrid distrito 05        Renta bruta media por persona     2022
# 11  2807905 Madrid distrito 05          Renta bruta media por hogar     2022
# 12  2807906 Madrid distrito 06        Renta bruta media por persona     2022
# 13  2807906 Madrid distrito 06          Renta bruta media por hogar     2022
# 14  2807907 Madrid distrito 07        Renta bruta media por persona     2022
# 15  2807907 Madrid distrito 07          Renta bruta media por hogar     2022
# 16  2807908 Madrid distrito 08        Renta bruta media por persona     2022
# 17  2807908 Madrid distrito 08          Renta bruta media por hogar     2022
# 18  2807909 Madrid distrito 09        Renta bruta media por persona     2022
# 19  2807909 Madrid distrito 09          Renta bruta media por hogar     2022
# 20  2807910 Madrid distrito 10        Renta bruta media por persona     2022
# 21  2807910 Madrid distrito 10          Renta bruta media por hogar     2022
# 22  2807911 Madrid distrito 11        Renta bruta media por persona     2022
# 23  2807911 Madrid distrito 11          Renta bruta media por hogar     2022
# 24  2807912 Madrid distrito 12        Renta bruta media por persona     2022
# 25  2807912 Madrid distrito 12          Renta bruta media por hogar     2022
# 26  2807913 Madrid distrito 13        Renta bruta media por persona     2022
# 27  2807913 Madrid distrito 13          Renta bruta media por hogar     2022
# 28  2807914 Madrid distrito 14        Renta bruta media por persona     2022
# 29  2807914 Madrid distrito 14          Renta bruta media por hogar     2022
# 30  2807915 Madrid distrito 15        Renta bruta media por persona     2022
# 31  2807915 Madrid distrito 15          Renta bruta media por hogar     2022
# 32  2807916 Madrid distrito 16        Renta bruta media por persona     2022
# 33  2807916 Madrid distrito 16          Renta bruta media por hogar     2022
# 34  2807917 Madrid distrito 17        Renta bruta media por persona     2022
# 35  2807917 Madrid distrito 17          Renta bruta media por hogar     2022
# 36  2807918 Madrid distrito 18        Renta bruta media por persona     2022
# 37  2807918 Madrid distrito 18          Renta bruta media por hogar     2022
# 38  2807919 Madrid distrito 19        Renta bruta media por persona     2022
# 39  2807919 Madrid distrito 19          Renta bruta media por hogar     2022
# 40  2807920 Madrid distrito 20        Renta bruta media por persona     2022
# 41  2807920 Madrid distrito 20          Renta bruta media por hogar     2022
# 42  2807921 Madrid distrito 21        Renta bruta media por persona     2022
# 43  2807921 Madrid distrito 21          Renta bruta media por hogar     2022
#
#       Total
# 0    23.984
# 1    60.049
# 2    27.030
# 3    53.908
# 4    27.431
# 5    63.160
# 6    33.396
# 7    79.868
# 8    38.751
# 9    89.407
# 10   42.678
# 11  104.706
# 12   22.890
# 13   53.816
# 14   36.934
# 15   81.889
# 16   28.798
# 17   76.386
# 18   36.592
# 19   93.541
# 20   17.267
# 21   42.843
# 22   15.239
# 23   40.339
# 24   13.481
# 25   37.737
# 26   13.354
# 27   35.380
# 28   20.091
# 29   49.289
# 30   22.440
# 31   55.112
# 32   29.047
# 33   76.741
# 34   13.604
# 35   38.269
# 36   17.346
# 37   44.960
# 38   18.214
# 39   48.513
# 40   19.768
# 41   51.558
# 42   27.125
# 43   70.909

# %% [markdown]
# Esto es muy farragoso, por tanto, voy a reorganizar los datos en nuevo dataframe, una fila por distrito y las columnas 'DISTRITO', 'RENTA BRUTA MEDIA POR PERSONA' y 'RENTA BRUTA MEDIA POR HOGAR'.

# %%
# Filtro las filas que contienen los valores de renta bruta media.
df_rentas= df_dataset3[df_dataset3['Indicadores de renta media y mediana'].isin(['Renta bruta media por persona', 'Renta bruta media por hogar'])]
# Creo una pivot table que se ajuste a mis necesidades.
df_rentas_pivot = df_rentas.pivot_table(index='Distritos',
                                columns='Indicadores de renta media y mediana',
                                values='Total',
                                aggfunc='first')
# Reseteo los nombres de las columnas.
df_rentas_pivot.columns.name = None
df_rentas_pivot.reset_index(inplace=True)
# Renombro las columnas.
df_rentas_pivot.rename(columns={
    'Distritos' : 'DISTRITO',
    'Renta bruta media por persona': 'RENTA BRUTA MEDIA POR PERSONA',
    'Renta bruta media por hogar': 'RENTA BRUTA MEDIA POR HOGAR'
}, inplace=True)

df_rentas_pivot = df_rentas_pivot[['DISTRITO', 'RENTA BRUTA MEDIA POR PERSONA', 'RENTA BRUTA MEDIA POR HOGAR']]
df_rentas_pivot = df_rentas_pivot.iloc[:, 1:]
df_rentas_pivot
# Out:
#     RENTA BRUTA MEDIA POR PERSONA  RENTA BRUTA MEDIA POR HOGAR
# 0                          27.030                       53.908
# 1                          27.431                       63.160
# 2                          33.396                       79.868
# 3                          38.751                       89.407
# 4                          42.678                      104.706
# 5                          22.890                       53.816
# 6                          36.934                       81.889
# 7                          28.798                       76.386
# 8                          36.592                       93.541
# 9                          17.267                       42.843
# 10                         15.239                       40.339
# 11                         13.481                       37.737
# 12                         13.354                       35.380
# 13                         20.091                       49.289
# 14                         22.440                       55.112
# 15                         29.047                       76.741
# 16                         13.604                       38.269
# 17                         17.346                       44.960
# 18                         18.214                       48.513
# 19                         19.768                       51.558
# 20                         27.125                       70.909

# %% [markdown]
# ##### **DATASET 4 - Distritos del municipio de Madrid, año 2023**

# %%
df_dataset4= pd.read_csv('./data/04_distritos_municipio_madrid.csv', encoding='ISO-8859-1', sep=';')
df_habkm2 = df_dataset4.iloc[:, -1:]
df_habkm2.columns = df_habkm2.columns.str.upper()
df_habkm2
# Out:
#     DENSIDAD_POR_KM2
# 0           25340.69
# 1           23306.44
# 2           21867.53
# 3           26830.78
# 4           15723.25
# 5           28664.25
# 6           29049.26
# 7            1003.00
# 8            2515.26
# 9            9183.75
# 10          17316.88
# 11          17535.32
# 12          15345.01
# 13          15493.59
# 14          18455.56
# 15           6973.33
# 16           7059.13
# 17           2026.82
# 18           1981.11
# 19           6934.37
# 20           1076.06

# %% [markdown]
# ##### **DATASET 5 - Población en Madrid por distrito a 1 de enero de 2023**

# %%
df_dataset5= pd.read_csv('./data/05_censo_poblacion_distritos.csv', sep=';')
df_dataset5= df_dataset5.head(21)
df_dataset5
# Out:
#                  fecha  cod_municipio municipio cod_distrito  \
# 0   1 de enero de 2023          28079    Madrid            1
# 1   1 de enero de 2023          28079    Madrid            2
# 2   1 de enero de 2023          28079    Madrid            3
# 3   1 de enero de 2023          28079    Madrid            4
# 4   1 de enero de 2023          28079    Madrid            5
# 5   1 de enero de 2023          28079    Madrid            6
# 6   1 de enero de 2023          28079    Madrid            7
# 7   1 de enero de 2023          28079    Madrid            8
# 8   1 de enero de 2023          28079    Madrid            9
# 9   1 de enero de 2023          28079    Madrid           10
# 10  1 de enero de 2023          28079    Madrid           11
# 11  1 de enero de 2023          28079    Madrid           12
# 12  1 de enero de 2023          28079    Madrid           13
# 13  1 de enero de 2023          28079    Madrid           14
# 14  1 de enero de 2023          28079    Madrid           15
# 15  1 de enero de 2023          28079    Madrid           16
# 16  1 de enero de 2023          28079    Madrid           17
# 17  1 de enero de 2023          28079    Madrid           18
# 18  1 de enero de 2023          28079    Madrid           19
# 19  1 de enero de 2023          28079    Madrid           20
# 20  1 de enero de 2023          28079    Madrid           21
#
#                 distrito cod_barrio                barrio num_personas  \
# 0                 Centro          1                Centro      139.687
# 1             Arganzuela          2            Arganzuela      153.304
# 2                 Retiro          3                Retiro      117.918
# 3              Salamanca          4             Salamanca      145.702
# 4              Chamartín          5             Chamartín      144.796
# 5                 Tetuán          6                Tetuán      160.002
# 6               Chamberí          7              Chamberí      138.204
# 7    Fuencarral-El Pardo          8   Fuencarral-El Pardo      248.443
# 8        Moncloa-Aravaca          9       Moncloa-Aravaca      121.757
# 9                 Latina         10                Latina      241.672
# 10           Carabanchel         11           Carabanchel      262.339
# 11                 Usera         12                 Usera      142.746
# 12    Puente de Vallecas         13    Puente de Vallecas      241.603
# 13             Moratalaz         14             Moratalaz       92.814
# 14         Ciudad Lineal         15         Ciudad Lineal      220.345
# 15             Hortaleza         16             Hortaleza      198.391
# 16            Villaverde         17            Villaverde      159.038
# 17     Villa de Vallecas         18     Villa de Vallecas      117.501
# 18             Vicálvaro         19             Vicálvaro       83.804
# 19   San Blas-Canillejas         20   San Blas-Canillejas      161.219
# 20               Barajas         21               Barajas       48.646
#
#    num_personas_hombres num_personas_mujeres
# 0                70.770               68.917
# 1                71.754               81.550
# 2                53.458               64.460
# 3                64.452               81.250
# 4                65.245               79.551
# 5                72.938               87.064
# 6                61.149               77.055
# 7               116.944              131.499
# 8                56.357               65.400
# 9               112.093              129.579
# 10              122.632              139.707
# 11               67.538               75.208
# 12              114.542              127.061
# 13               42.212               50.602
# 14              100.759              119.586
# 15               94.100              104.291
# 16               76.131               82.907
# 17               56.726               60.775
# 18               40.580               43.224
# 19               76.154               85.065
# 20               23.332               25.314

# %%
# Selecciono desde la quinta columna hasta la última. 
df_dataset5 = df_dataset5.iloc[:, 4:]
# Cambio el nombre de la columna 'cod_barrio' a 'cod_distrito'.
df_dataset5.columns = df_dataset5.columns.str.replace('cod_barrio','cod_distrito')
# Elimino la columna 'barrio'
df_dataset5 = df_dataset5.drop(['barrio','num_personas_hombres','num_personas_mujeres'], axis = 1 )
# Convierto los títulos de las columnas en mayúsculas.
df_dataset5.columns = df_dataset5.columns.str.upper()
df_dataset5.dtypes
# Out:
# DISTRITO        object
# COD_DISTRITO    object
# NUM_PERSONAS    object
# dtype: object

# %%
# Convierto los datos de la columna 'NUM_PERSONAS' en Float64
df_dataset5['NUM_PERSONAS'] = df_dataset5['NUM_PERSONAS'].astype('Float64')
df_poblacion = df_dataset5
df_poblacion
# Out:
#                 DISTRITO COD_DISTRITO  NUM_PERSONAS
# 0                 Centro            1       139.687
# 1             Arganzuela            2       153.304
# 2                 Retiro            3       117.918
# 3              Salamanca            4       145.702
# 4              Chamartín            5       144.796
# 5                 Tetuán            6       160.002
# 6               Chamberí            7       138.204
# 7    Fuencarral-El Pardo            8       248.443
# 8        Moncloa-Aravaca            9       121.757
# 9                 Latina           10       241.672
# 10           Carabanchel           11       262.339
# 11                 Usera           12       142.746
# 12    Puente de Vallecas           13       241.603
# 13             Moratalaz           14        92.814
# 14         Ciudad Lineal           15       220.345
# 15             Hortaleza           16       198.391
# 16            Villaverde           17       159.038
# 17     Villa de Vallecas           18       117.501
# 18             Vicálvaro           19        83.804
# 19   San Blas-Canillejas           20       161.219
# 20               Barajas           21        48.646

# %%
# Unifico los datasets 4 y 5.
df_poblacion = pd.concat([df_poblacion, df_habkm2], axis=1)
df_poblacion
df_poblacion = df_poblacion.drop(df_poblacion.columns[1], axis=1)
df_poblacion
# Out:
#                 DISTRITO  NUM_PERSONAS  DENSIDAD_POR_KM2
# 0                 Centro       139.687          25340.69
# 1             Arganzuela       153.304          23306.44
# 2                 Retiro       117.918          21867.53
# 3              Salamanca       145.702          26830.78
# 4              Chamartín       144.796          15723.25
# 5                 Tetuán       160.002          28664.25
# 6               Chamberí       138.204          29049.26
# 7    Fuencarral-El Pardo       248.443           1003.00
# 8        Moncloa-Aravaca       121.757           2515.26
# 9                 Latina       241.672           9183.75
# 10           Carabanchel       262.339          17316.88
# 11                 Usera       142.746          17535.32
# 12    Puente de Vallecas       241.603          15345.01
# 13             Moratalaz        92.814          15493.59
# 14         Ciudad Lineal       220.345          18455.56
# 15             Hortaleza       198.391           6973.33
# 16            Villaverde       159.038           7059.13
# 17     Villa de Vallecas       117.501           2026.82
# 18             Vicálvaro        83.804           1981.11
# 19   San Blas-Canillejas       161.219           6934.37
# 20               Barajas        48.646           1076.06

# %%
df_densidadpoblacion = df_poblacion.drop('NUM_PERSONAS', axis = 1 )
df_densidadpoblacion
# Out:
#                 DISTRITO  DENSIDAD_POR_KM2
# 0                 Centro          25340.69
# 1             Arganzuela          23306.44
# 2                 Retiro          21867.53
# 3              Salamanca          26830.78
# 4              Chamartín          15723.25
# 5                 Tetuán          28664.25
# 6               Chamberí          29049.26
# 7    Fuencarral-El Pardo           1003.00
# 8        Moncloa-Aravaca           2515.26
# 9                 Latina           9183.75
# 10           Carabanchel          17316.88
# 11                 Usera          17535.32
# 12    Puente de Vallecas          15345.01
# 13             Moratalaz          15493.59
# 14         Ciudad Lineal          18455.56
# 15             Hortaleza           6973.33
# 16            Villaverde           7059.13
# 17     Villa de Vallecas           2026.82
# 18             Vicálvaro           1981.11
# 19   San Blas-Canillejas           6934.37
# 20               Barajas           1076.06

# %%
# Uno al df_rentas_pivot la columna 'DISTRITO' del dataset 5 para obtener una tabla de rentas brutas. 
primera_columna_dataset5 =df_poblacion.iloc[:, 0]
df_rentas = pd.concat([primera_columna_dataset5, df_rentas_pivot], axis=1)
df_rentas
# Out:
#                 DISTRITO  RENTA BRUTA MEDIA POR PERSONA  \
# 0                 Centro                         27.030
# 1             Arganzuela                         27.431
# 2                 Retiro                         33.396
# 3              Salamanca                         38.751
# 4              Chamartín                         42.678
# 5                 Tetuán                         22.890
# 6               Chamberí                         36.934
# 7    Fuencarral-El Pardo                         28.798
# 8        Moncloa-Aravaca                         36.592
# 9                 Latina                         17.267
# 10           Carabanchel                         15.239
# 11                 Usera                         13.481
# 12    Puente de Vallecas                         13.354
# 13             Moratalaz                         20.091
# 14         Ciudad Lineal                         22.440
# 15             Hortaleza                         29.047
# 16            Villaverde                         13.604
# 17     Villa de Vallecas                         17.346
# 18             Vicálvaro                         18.214
# 19   San Blas-Canillejas                         19.768
# 20               Barajas                         27.125
#
#     RENTA BRUTA MEDIA POR HOGAR
# 0                        53.908
# 1                        63.160
# 2                        79.868
# 3                        89.407
# 4                       104.706
# 5                        53.816
# 6                        81.889
# 7                        76.386
# 8                        93.541
# 9                        42.843
# 10                       40.339
# 11                       37.737
# 12                       35.380
# 13                       49.289
# 14                       55.112
# 15                       76.741
# 16                       38.269
# 17                       44.960
# 18                       48.513
# 19                       51.558
# 20                       70.909

# %%
# Unifico el resultado de limpiar los datasets 4 y 5 con el dataset 3
df_datosobjetoestudio = pd.concat([df_poblacion, df_rentas_pivot], axis=1)
df_datosobjetoestudio
# Out:
#                 DISTRITO  NUM_PERSONAS  DENSIDAD_POR_KM2  \
# 0                 Centro       139.687          25340.69
# 1             Arganzuela       153.304          23306.44
# 2                 Retiro       117.918          21867.53
# 3              Salamanca       145.702          26830.78
# 4              Chamartín       144.796          15723.25
# 5                 Tetuán       160.002          28664.25
# 6               Chamberí       138.204          29049.26
# 7    Fuencarral-El Pardo       248.443           1003.00
# 8        Moncloa-Aravaca       121.757           2515.26
# 9                 Latina       241.672           9183.75
# 10           Carabanchel       262.339          17316.88
# 11                 Usera       142.746          17535.32
# 12    Puente de Vallecas       241.603          15345.01
# 13             Moratalaz        92.814          15493.59
# 14         Ciudad Lineal       220.345          18455.56
# 15             Hortaleza       198.391           6973.33
# 16            Villaverde       159.038           7059.13
# 17     Villa de Vallecas       117.501           2026.82
# 18             Vicálvaro        83.804           1981.11
# 19   San Blas-Canillejas       161.219           6934.37
# 20               Barajas        48.646           1076.06
#
#     RENTA BRUTA MEDIA POR PERSONA  RENTA BRUTA MEDIA POR HOGAR
# 0                          27.030                       53.908
# 1                          27.431                       63.160
# 2                          33.396                       79.868
# 3                          38.751                       89.407
# 4                          42.678                      104.706
# 5                          22.890                       53.816
# 6                          36.934                       81.889
# 7                          28.798                       76.386
# 8                          36.592                       93.541
# 9                          17.267                       42.843
# 10                         15.239                       40.339
# 11                         13.481                       37.737
# 12                         13.354                       35.380
# 13                         20.091                       49.289
# 14                         22.440                       55.112
# 15                         29.047                       76.741
# 16                         13.604                       38.269
# 17                         17.346                       44.960
# 18                         18.214                       48.513
# 19                         19.768                       51.558
# 20                         27.125                       70.909

# %% [markdown]
# ##### **DATASET 6 - Superficie de parques y zonas verdes por distrito en Madrid, año 2023**

# %%
df_dataset6 = pd.read_csv('./data/06_SuperficieZonasVerdesDistritosCalles_2023.csv', sep=';')
df_dataset6 = df_dataset6.head(21)
df_dataset6
# Out:
#     Nº Distrito               DISTRITO m2 de ZONAS VERDES Y PARQUES  \
# 0             1                 Centro                   314.769,26
# 1             2             Arganzuela                   907.120,00
# 2             3                 Retiro                   376.361,47
# 3             4              Salamanca                   357.930,25
# 4             5              Chamartín                   564.117,25
# 5             6                 Tetuán                   636.986,99
# 6             7               Chamberí                    98.964,58
# 7             8  Fuencarral - El Pardo                 3.681.910,80
# 8             9      Moncloa - Aravaca                 1.874.662,40
# 9            10                 Latina                 2.769.509,80
# 10           11            Carabanchel                 2.297.580,00
# 11           12                  Usera                 1.678.460,00
# 12           13     Puente de Vallecas                 2.795.790,00
# 13           14              Moratalaz                 1.178.110,00
# 14           15          Ciudad Lineal                 1.336.681,77
# 15           16              Hortaleza                 3.235.899,30
# 16           17             Villaverde                 2.161.050,00
# 17           18      Villa de Vallecas                 3.092.940,00
# 18           19              Vicálvaro                 1.955.250,00
# 19           20  San Blas - Canillejas                 1.750.213,30
# 20           21                Barajas                 1.016.820,31
#
#    ha de ZONAS VERDES Y PARQUES
# 0                         31,48
# 1                         90,71
# 2                         37,64
# 3                         35,79
# 4                         56,41
# 5                          63,7
# 6                           9,9
# 7                        368,19
# 8                        187,47
# 9                        276,95
# 10                       229,76
# 11                       167,85
# 12                       279,58
# 13                       117,81
# 14                       133,67
# 15                       323,59
# 16                       216,11
# 17                       309,29
# 18                       195,53
# 19                       175,02
# 20                       101,68

# %%
# Selecciono la cuarta columna del df.
df_dataset6 = df_dataset6.iloc[:,[1,3]]
print(df_dataset6['ha de ZONAS VERDES Y PARQUES'].dtype)
# Cambio los decimales de los datos por puntos 
df_dataset6['ha de ZONAS VERDES Y PARQUES'] = df_dataset6['ha de ZONAS VERDES Y PARQUES'].str.replace(',','.')
# Convierto los datos de la columna en Float64
df_dataset6['ha de ZONAS VERDES Y PARQUES'] = df_dataset6['ha de ZONAS VERDES Y PARQUES'].astype('Float64')
print(df_dataset6['ha de ZONAS VERDES Y PARQUES'].dtype)
df_parqueszonasverdes = df_dataset6
df_parqueszonasverdes
# Out:
# object
# Float64
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2959780922.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dataset6['ha de ZONAS VERDES Y PARQUES'] = df_dataset6['ha de ZONAS VERDES Y PARQUES'].str.replace(',','.')
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2959780922.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_dataset6['ha de ZONAS VERDES Y PARQUES'] = df_dataset6['ha de ZONAS VERDES Y PARQUES'].astype('Float64')
#                  DISTRITO  ha de ZONAS VERDES Y PARQUES
# 0                  Centro                         31.48
# 1              Arganzuela                         90.71
# 2                  Retiro                         37.64
# 3               Salamanca                         35.79
# 4               Chamartín                         56.41
# 5                  Tetuán                          63.7
# 6                Chamberí                           9.9
# 7   Fuencarral - El Pardo                        368.19
# 8       Moncloa - Aravaca                        187.47
# 9                  Latina                        276.95
# 10            Carabanchel                        229.76
# 11                  Usera                        167.85
# 12     Puente de Vallecas                        279.58
# 13              Moratalaz                        117.81
# 14          Ciudad Lineal                        133.67
# 15              Hortaleza                        323.59
# 16             Villaverde                        216.11
# 17      Villa de Vallecas                        309.29
# 18              Vicálvaro                        195.53
# 19  San Blas - Canillejas                        175.02
# 20                Barajas                        101.68

# %%
# Uno la última columna del dataset 6 al dataframe con los datos objeto de estudio.
df_datosobjetoestudio = pd.concat([df_datosobjetoestudio, df_parqueszonasverdes.iloc[:,-1:]], axis=1)
df_datosobjetoestudio
# Out:
#                 DISTRITO  NUM_PERSONAS  DENSIDAD_POR_KM2  \
# 0                 Centro       139.687          25340.69
# 1             Arganzuela       153.304          23306.44
# 2                 Retiro       117.918          21867.53
# 3              Salamanca       145.702          26830.78
# 4              Chamartín       144.796          15723.25
# 5                 Tetuán       160.002          28664.25
# 6               Chamberí       138.204          29049.26
# 7    Fuencarral-El Pardo       248.443           1003.00
# 8        Moncloa-Aravaca       121.757           2515.26
# 9                 Latina       241.672           9183.75
# 10           Carabanchel       262.339          17316.88
# 11                 Usera       142.746          17535.32
# 12    Puente de Vallecas       241.603          15345.01
# 13             Moratalaz        92.814          15493.59
# 14         Ciudad Lineal       220.345          18455.56
# 15             Hortaleza       198.391           6973.33
# 16            Villaverde       159.038           7059.13
# 17     Villa de Vallecas       117.501           2026.82
# 18             Vicálvaro        83.804           1981.11
# 19   San Blas-Canillejas       161.219           6934.37
# 20               Barajas        48.646           1076.06
#
#     RENTA BRUTA MEDIA POR PERSONA  RENTA BRUTA MEDIA POR HOGAR  \
# 0                          27.030                       53.908
# 1                          27.431                       63.160
# 2                          33.396                       79.868
# 3                          38.751                       89.407
# 4                          42.678                      104.706
# 5                          22.890                       53.816
# 6                          36.934                       81.889
# 7                          28.798                       76.386
# 8                          36.592                       93.541
# 9                          17.267                       42.843
# 10                         15.239                       40.339
# 11                         13.481                       37.737
# 12                         13.354                       35.380
# 13                         20.091                       49.289
# 14                         22.440                       55.112
# 15                         29.047                       76.741
# 16                         13.604                       38.269
# 17                         17.346                       44.960
# 18                         18.214                       48.513
# 19                         19.768                       51.558
# 20                         27.125                       70.909
#
#     ha de ZONAS VERDES Y PARQUES
# 0                          31.48
# 1                          90.71
# 2                          37.64
# 3                          35.79
# 4                          56.41
# 5                           63.7
# 6                            9.9
# 7                         368.19
# 8                         187.47
# 9                         276.95
# 10                        229.76
# 11                        167.85
# 12                        279.58
# 13                        117.81
# 14                        133.67
# 15                        323.59
# 16                        216.11
# 17                        309.29
# 18                        195.53
# 19                        175.02
# 20                        101.68

# %% [markdown]
# ##### **DATASET 7 - Padrón de vehículos por distrito en Madrid, año 2023**

# %%
import chardet

with open('./data/07_O12110124_cl.csv', 'rb') as file:
    result = chardet.detect(file.read())
    print(result)
# Out:
# {'encoding': 'MacRoman', 'confidence': 0.7246559297218155, 'language': ''}

# %%
df_dataset7 = pd.read_csv('./data/07_O12110124_cl.csv', sep=';', encoding='MacRoman')
df_dataset7 = df_dataset7.drop(index=0) # Elimino la primera fila, que muestra un total a nivel de Madrid
df_dataset7
# Out:
#                  DISTRITO TURISMOS  AUTOBUSES  CAMIONES  REMOLQUES   MOTOS  \
# 1                  Centro   42.250      93.00     5.373    361.000  10.396
# 2              Arganzuela   56.954     214.00     3.745    375.000   8.405
# 3                  Retiro   51.148       2.44     3.932    233.000   8.983
# 4               Salamanca   63.881     135.00     6.975      1.195  12.760
# 5               Chamartín   69.875     109.00     7.375    600.000  12.847
# 6                  Tetuán   58.064      28.00     6.402      1.040  10.048
# 7                Chamberí   55.829      37.00     4.827    688.000  11.053
# 8   Fuencarral - El Pardo  104.987      45.00     5.816    316.000  14.445
# 9       Moncloa - Aravaca   52.877      74.00     3.953    402.000   8.832
# 10                 Latina   84.597      27.00     6.961    263.000   9.595
# 11            Carabanchel   84.462     120.00     9.072    213.000  11.076
# 12                  Usera   45.236      39.00     5.458    159.000   5.323
# 13     Puente de Vallecas   79.818      53.00     9.107    271.000   9.960
# 14              Moratalaz   35.777      45.00     2.587    241.000   4.599
# 15          Ciudad Lineal   82.631      68.00     8.996    367.000  12.790
# 16              Hortaleza   80.879     141.00     5.587    499.000  12.270
# 17             Villaverde   54.717     418.00     6.736    444.000   5.032
# 18      Villa de Vallecas   43.475      34.00     5.254    257.000   5.325
# 19              Vicálvaro   30.439      37.00     2.972    115.000   3.884
# 20  San Blas - Canillejas   63.621     574.00     6.465    332.000   8.508
# 21                Barajas   22.183      36.00     2.274    113.000   4.190
#
#     CICLOMOTORES  TRACTORES TOTAL_VEHÍCULOS
# 1          1.688    710.000          60.871
# 2          1.171    932.000          71.796
# 3          1.249    706.000          68.691
# 4          1.780      1.736          88.462
# 5          3.133      1.491          95.430
# 6          2.138      1.358          79.078
# 7          1.558      1.022          75.014
# 8          2.072    790.000         128.471
# 9          4.522    629.000          71.289
# 10         1.948    538.000         103.929
# 11         2.540    560.000         108.043
# 12         1.447    394.000          58.056
# 13         2.815    665.000         102.689
# 14       988.000    289.000          44.526
# 15         2.582      1.202         108.636
# 16         2.011      1.087         102.474
# 17         1.238    536.000          69.121
# 18       894.000    647.000          55.886
# 19       603.000    315.000          38.365
# 20         1.665    708.000          81.873
# 21       392.000    227.000          29.415

# %% [markdown]
# Este archivo parte de un xlsl que he convertido en un csv con Excel, entonces hay que reorganizar los datos por una cuestión de conversión del diseño de la tabla original. Investigando di con la librería chardet para detectar la codificación del archivo, dado que con la genérica los caracteres acentuados no tenían una legibilidad adecuada.

# %%
df_dataset7.dtypes
# Out:
# DISTRITO            object
# TURISMOS            object
# AUTOBUSES          float64
# CAMIONES           float64
# REMOLQUES          float64
# MOTOS              float64
# CICLOMOTORES       float64
# TRACTORES          float64
# TOTAL_VEHÍCULOS     object
# dtype: object

# %% [markdown]
# Con esto observo que hay datos que son de tipo object y he de convertirlos en float64.

# %%
df_dataset7['AUTOBUSES'] = df_dataset7['AUTOBUSES'].round().astype('Int64')
df_dataset7['REMOLQUES'] = df_dataset7['REMOLQUES'].round().astype('Int64')
df_dataset7['CICLOMOTORES'] = df_dataset7['CICLOMOTORES'].round().astype('Int64')
df_dataset7['TRACTORES'] = df_dataset7['TRACTORES'].round().astype('Int64')
df_dataset7['TOTAL_VEHÍCULOS'] = df_dataset7['TOTAL_VEHÍCULOS'].astype('Float64') 
# Al convertir 'TOTAL_VEHÍCULOS' en Float64 se me altera el valor de Chamartín y pasa de 95.430 a 95.43, lo corrijo.
df_dataset7.loc[df_dataset7['DISTRITO'] == 'Chamartin', 'TOTAL_VEHÍCULOS'] = 95.430
df_dataset7=df_dataset7.reset_index(drop=True)
df_dataset7
# Out:
#                  DISTRITO TURISMOS  AUTOBUSES  CAMIONES  REMOLQUES   MOTOS  \
# 0                  Centro   42.250         93     5.373        361  10.396
# 1              Arganzuela   56.954        214     3.745        375   8.405
# 2                  Retiro   51.148          2     3.932        233   8.983
# 3               Salamanca   63.881        135     6.975          1  12.760
# 4               Chamartín   69.875        109     7.375        600  12.847
# 5                  Tetuán   58.064         28     6.402          1  10.048
# 6                Chamberí   55.829         37     4.827        688  11.053
# 7   Fuencarral - El Pardo  104.987         45     5.816        316  14.445
# 8       Moncloa - Aravaca   52.877         74     3.953        402   8.832
# 9                  Latina   84.597         27     6.961        263   9.595
# 10            Carabanchel   84.462        120     9.072        213  11.076
# 11                  Usera   45.236         39     5.458        159   5.323
# 12     Puente de Vallecas   79.818         53     9.107        271   9.960
# 13              Moratalaz   35.777         45     2.587        241   4.599
# 14          Ciudad Lineal   82.631         68     8.996        367  12.790
# 15              Hortaleza   80.879        141     5.587        499  12.270
# 16             Villaverde   54.717        418     6.736        444   5.032
# 17      Villa de Vallecas   43.475         34     5.254        257   5.325
# 18              Vicálvaro   30.439         37     2.972        115   3.884
# 19  San Blas - Canillejas   63.621        574     6.465        332   8.508
# 20                Barajas   22.183         36     2.274        113   4.190
#
#     CICLOMOTORES  TRACTORES  TOTAL_VEHÍCULOS
# 0              2        710           60.871
# 1              1        932           71.796
# 2              1        706           68.691
# 3              2          2           88.462
# 4              3          1            95.43
# 5              2          1           79.078
# 6              2          1           75.014
# 7              2        790          128.471
# 8              5        629           71.289
# 9              2        538          103.929
# 10             3        560          108.043
# 11             1        394           58.056
# 12             3        665          102.689
# 13           988        289           44.526
# 14             3          1          108.636
# 15             2          1          102.474
# 16             1        536           69.121
# 17           894        647           55.886
# 18           603        315           38.365
# 19             2        708           81.873
# 20           392        227           29.415

# %%
# Selecciono sólo la primera y la última columna del dataframe
df_dataset7 = df_dataset7.iloc[:,[0,-1]]
df_dataset7.columns = df_dataset7.columns.str.replace('TOTAL_VEHÍCULOS', 'TOTAL_VEHICULOS')
df_vehiculos = df_dataset7
df_vehiculos
# Out:
#                  DISTRITO  TOTAL_VEHICULOS
# 0                  Centro           60.871
# 1              Arganzuela           71.796
# 2                  Retiro           68.691
# 3               Salamanca           88.462
# 4               Chamartín            95.43
# 5                  Tetuán           79.078
# 6                Chamberí           75.014
# 7   Fuencarral - El Pardo          128.471
# 8       Moncloa - Aravaca           71.289
# 9                  Latina          103.929
# 10            Carabanchel          108.043
# 11                  Usera           58.056
# 12     Puente de Vallecas          102.689
# 13              Moratalaz           44.526
# 14          Ciudad Lineal          108.636
# 15              Hortaleza          102.474
# 16             Villaverde           69.121
# 17      Villa de Vallecas           55.886
# 18              Vicálvaro           38.365
# 19  San Blas - Canillejas           81.873
# 20                Barajas           29.415

# %%
# Para estudiar una de mis hipótesis necesito saber el número de habitantes por vehículo en cada distrito
df_habitantesyvehiculo = pd.concat([df_poblacion.drop('DENSIDAD_POR_KM2', axis=1), df_vehiculos.iloc[:,-1:]], axis=1)
df_habitantesyvehiculo['HAB/COCHE'] = df_habitantesyvehiculo['NUM_PERSONAS'].astype('float64') / df_habitantesyvehiculo['TOTAL_VEHICULOS'].astype('float64')
df_habitantesyvehiculo['HAB/COCHE'] = df_habitantesyvehiculo['HAB/COCHE'].round(2)
df_habitantesyvehiculo
# Out:
#                 DISTRITO  NUM_PERSONAS  TOTAL_VEHICULOS  HAB/COCHE
# 0                 Centro       139.687           60.871       2.29
# 1             Arganzuela       153.304           71.796       2.14
# 2                 Retiro       117.918           68.691       1.72
# 3              Salamanca       145.702           88.462       1.65
# 4              Chamartín       144.796            95.43       1.52
# 5                 Tetuán       160.002           79.078       2.02
# 6               Chamberí       138.204           75.014       1.84
# 7    Fuencarral-El Pardo       248.443          128.471       1.93
# 8        Moncloa-Aravaca       121.757           71.289       1.71
# 9                 Latina       241.672          103.929       2.33
# 10           Carabanchel       262.339          108.043       2.43
# 11                 Usera       142.746           58.056       2.46
# 12    Puente de Vallecas       241.603          102.689       2.35
# 13             Moratalaz        92.814           44.526       2.08
# 14         Ciudad Lineal       220.345          108.636       2.03
# 15             Hortaleza       198.391          102.474       1.94
# 16            Villaverde       159.038           69.121       2.30
# 17     Villa de Vallecas       117.501           55.886       2.10
# 18             Vicálvaro        83.804           38.365       2.18
# 19   San Blas-Canillejas       161.219           81.873       1.97
# 20               Barajas        48.646           29.415       1.65

# %%
# Uno la última columna del dataset 7 al dataframe con los datos objeto de estudio.
df_datosobjetoestudio = pd.concat([df_datosobjetoestudio, df_habitantesyvehiculo.iloc[:,-2:]], axis=1)
df_datosobjetoestudio
# Out:
#                 DISTRITO  NUM_PERSONAS  DENSIDAD_POR_KM2  \
# 0                 Centro       139.687          25340.69
# 1             Arganzuela       153.304          23306.44
# 2                 Retiro       117.918          21867.53
# 3              Salamanca       145.702          26830.78
# 4              Chamartín       144.796          15723.25
# 5                 Tetuán       160.002          28664.25
# 6               Chamberí       138.204          29049.26
# 7    Fuencarral-El Pardo       248.443           1003.00
# 8        Moncloa-Aravaca       121.757           2515.26
# 9                 Latina       241.672           9183.75
# 10           Carabanchel       262.339          17316.88
# 11                 Usera       142.746          17535.32
# 12    Puente de Vallecas       241.603          15345.01
# 13             Moratalaz        92.814          15493.59
# 14         Ciudad Lineal       220.345          18455.56
# 15             Hortaleza       198.391           6973.33
# 16            Villaverde       159.038           7059.13
# 17     Villa de Vallecas       117.501           2026.82
# 18             Vicálvaro        83.804           1981.11
# 19   San Blas-Canillejas       161.219           6934.37
# 20               Barajas        48.646           1076.06
#
#     RENTA BRUTA MEDIA POR PERSONA  RENTA BRUTA MEDIA POR HOGAR  \
# 0                          27.030                       53.908
# 1                          27.431                       63.160
# 2                          33.396                       79.868
# 3                          38.751                       89.407
# 4                          42.678                      104.706
# 5                          22.890                       53.816
# 6                          36.934                       81.889
# 7                          28.798                       76.386
# 8                          36.592                       93.541
# 9                          17.267                       42.843
# 10                         15.239                       40.339
# 11                         13.481                       37.737
# 12                         13.354                       35.380
# 13                         20.091                       49.289
# 14                         22.440                       55.112
# 15                         29.047                       76.741
# 16                         13.604                       38.269
# 17                         17.346                       44.960
# 18                         18.214                       48.513
# 19                         19.768                       51.558
# 20                         27.125                       70.909
#
#     ha de ZONAS VERDES Y PARQUES  TOTAL_VEHICULOS  HAB/COCHE
# 0                          31.48           60.871       2.29
# 1                          90.71           71.796       2.14
# 2                          37.64           68.691       1.72
# 3                          35.79           88.462       1.65
# 4                          56.41            95.43       1.52
# 5                           63.7           79.078       2.02
# 6                            9.9           75.014       1.84
# 7                         368.19          128.471       1.93
# 8                         187.47           71.289       1.71
# 9                         276.95          103.929       2.33
# 10                        229.76          108.043       2.43
# 11                        167.85           58.056       2.46
# 12                        279.58          102.689       2.35
# 13                        117.81           44.526       2.08
# 14                        133.67          108.636       2.03
# 15                        323.59          102.474       1.94
# 16                        216.11           69.121       2.30
# 17                        309.29           55.886       2.10
# 18                        195.53           38.365       2.18
# 19                        175.02           81.873       1.97
# 20                        101.68           29.415       1.65

# %% [markdown]
# ##### **DATASET 8 - Medios de transporte por distrito en Madrid, año 2023**

# %%
df_dataset8 = pd.read_csv('./data/08_mediosdetransportedistrito2023.csv', sep=';', encoding='MacRoman')
df_movilidadytransporte = df_dataset8.drop(0).reset_index(drop=True)
df_movilidadytransporte
# Out:
#                  DISTRITO Metro/metro ligero Autobús urbano Coche particular  \
# 0                  Centro               68,4           61,2             43,3
# 1              Arganzuela               73,2           73,9               45
# 2                  Retiro                 59           71,3               42
# 3               Salamanca                 64             74             41,7
# 4               Chamartín               60,5           66,7             41,8
# 5                  Tetuán               71,1           68,1             39,9
# 6                Chamberí               66,9           59,8             37,2
# 7   Fuencarral - El Pardo               62,3           53,7               59
# 8       Moncloa - Aravaca               59,2           53,1             56,3
# 9                  Latina               81,8             71             44,3
# 10            Carabanchel                 70           64,6             45,5
# 11                  Usera               62,9           64,6             50,3
# 12     Puente de Vallecas               59,2           65,2             46,2
# 13              Moratalaz               62,3           72,5             52,8
# 14          Ciudad Lineal               69,4           69,3             51,1
# 15              Hortaleza               66,9           50,1             58,3
# 16             Villaverde               64,4           51,4               44
# 17      Villa de Vallecas               64,5           46,5             63,8
# 18              Vicálvaro               54,7           50,4             66,8
# 19  San Blas - Canillejas               67,9           66,8             60,2
# 20                Barajas               67,8           40,8             70,6
#
#    Tren de cercanías  Taxi  \
# 0               21,7    20
# 1               25,5  16,9
# 2               20,3  28,1
# 3               14,7    31
# 4               12,7  21,1
# 5               12,1  13,1
# 6                 12  25,9
# 7               15,6   8,3
# 8               20,1  21,5
# 9                 33  15,6
# 10                23  14,7
# 11              27,9   8,3
# 12              37,7  11,2
# 13               8,6  16,7
# 14              11,5  19,6
# 15              12,3   7,8
# 16              47,4  16,6
# 17              36,4   6,2
# 18              15,2   9,7
# 19               7,8  15,1
# 20               3,8  10,3
#
#    Servicios de VTC (vehículos de transporte con conductor)  \
# 0                                                  18
# 1                                                16,5
# 2                                                12,8
# 3                                                24,4
# 4                                                  19
# 5                                                14,9
# 6                                                15,4
# 7                                                11,2
# 8                                                12,5
# 9                                                  12
# 10                                               10,8
# 11                                                8,7
# 12                                               11,1
# 13                                               14,8
# 14                                               12,3
# 15                                               14,3
# 16                                                 11
# 17                                                7,6
# 18                                               12,1
# 19                                               14,6
# 20                                               16,5
#
#    Autobús interurbano Bicicleta Moto particular  \
# 0                 15,3       8,8             5,8
# 1                  7,4       9,9               4
# 2                    5       6,1             5,8
# 3                 10,5       6,4             7,9
# 4                  6,4       6,9             9,3
# 5                  6,4       8,7             9,9
# 6                  9,6       7,1             5,7
# 7                  9,6       4,6             3,3
# 8                 15,6       5,5             8,1
# 9                 10,9       5,2             5,9
# 10                14,9       5,7               4
# 11                 8,9       8,1             6,2
# 12                 5,7       3,2             2,7
# 13                 8,2       3,9             5,4
# 14                12,2       6,5             5,7
# 15                 8,9       7,7             5,3
# 16                10,2       5,4             6,3
# 17                 4,7       4,1             3,7
# 18                 5,4       4,9             6,2
# 19                12,3       5,5             3,7
# 20                   7       4,9             7,5
#
#    Servicios de alquiler de coches y/o motos por minutos Otros medios  \
# 0                                                 2,4             2,2
# 1                                                 5,7             1,5
# 2                                                 5,8             3,5
# 3                                                   8               4
# 4                                                 3,5             1,9
# 5                                                 4,5             3,1
# 6                                                 2,6             5,1
# 7                                                 4,4             2,4
# 8                                                 2,6             1,3
# 9                                                 0,5             1,9
# 10                                                2,7             4,3
# 11                                                1,1             2,2
# 12                                                1,2             1,5
# 13                                                3,3             3,1
# 14                                                3,9             0,5
# 15                                                5,5             2,4
# 16                                                  1             1,2
# 17                                                2,4             0,5
# 18                                                1,8             1,1
# 19                                                0,5             2,5
# 20                                                1,6               1
#
#    Transporte de empresa Transporte escolar  \
# 0                    2,4                2,5
# 1                    2,4                0,5
# 2                    2,1                  -
# 3                    1,2                0,5
# 4                    2,2                  -
# 5                      1                  -
# 6                    1,8                0,5
# 7                    1,2                0,4
# 8                    0,6                1,3
# 9                    0,7                0,9
# 10                   1,6                  -
# 11                   0,5                0,5
# 12                     1                  -
# 13                   1,1                  -
# 14                     1                  -
# 15                   2,6                  -
# 16                   0,5                1,1
# 17                   0,6                  -
# 18                   1,7                0,5
# 19                   1,6                  -
# 20                     0                  -
#
#    Servicios de alquiler de patinetes por minutos  \
# 0                                             1,8
# 1                                               1
# 2                                             1,1
# 3                                             0,6
# 4                                               -
# 5                                             1,3
# 6                                               -
# 7                                             0,6
# 8                                               -
# 9                                               -
# 10                                              -
# 11                                            0,5
# 12                                              -
# 13                                              -
# 14                                              -
# 15                                              -
# 16                                              -
# 17                                              -
# 18                                            0,6
# 19                                              -
# 20                                            0,6
#
#    Generalmente no utilizo ningún medio de transporte  \
# 0                                                 4,2
# 1                                                 2,4
# 2                                                 3,4
# 3                                                 3,1
# 4                                                 5,8
# 5                                                 4,4
# 6                                                 4,6
# 7                                                 3,6
# 8                                                 2,2
# 9                                                 1,1
# 10                                                1,9
# 11                                                2,7
# 12                                                3,1
# 13                                                  3
# 14                                                3,2
# 15                                                3,3
# 16                                                1,5
# 17                                                  1
# 18                                                1,6
# 19                                                  2
# 20                                                1,2
#
#    Media de medios utilizados
# 0                         2,7
# 1                         2,8
# 2                         2,6
# 3                         2,9
# 4                         2,5
# 5                         2,5
# 6                         2,5
# 7                         2,4
# 8                         2,6
# 9                         2,8
# 10                        2,6
# 11                        2,5
# 12                        2,5
# 13                        2,5
# 14                        2,6
# 15                        2,4
# 16                        2,6
# 17                        2,4
# 18                        2,3
# 19                        2,6
# 20                        2,3

# %% [markdown]
# Esta último DataFrame lo he creado en un documento Excel a partir de la tabla que se puede encontrar en la página 9 de este [PDF]('https://www.madrid.es/UnidadesDescentralizadas/Calidad/Observatorio_Ciudad/06_S_Percepcion/EncuestasCalidad/EncuestaMadrides/ficheros/2023/AA/Movilidad_Transporte.pdf'). Para su creación me fue de gran ayuda la función "Transponer" que recoge el "Pegado Especial" de Excel, esto me permitió convertir ágilmente filas de datos en columnas y viceversa.

# %% [markdown]
# De todos estos valores me parece más representativo quedarme con el porcentaje de personas por DISTRITO que manifiestan recurrir con normalidad al 'Coche particular' para desplazarse por la ciudad de Madrid.

# %%
df_cocheparticular = df_movilidadytransporte[['DISTRITO','Coche particular']]
df_cocheparticular.columns = df_cocheparticular.columns.str.replace('Coche particular', 'USO COCHE PARTICULAR')
print(df_cocheparticular['USO COCHE PARTICULAR'].dtype)
# Cambio los decimales de los datos por puntos 
df_cocheparticular['USO COCHE PARTICULAR'] = df_cocheparticular['USO COCHE PARTICULAR'].str.replace(',','.')
# Convierto los datos de la columna en Float64
df_cocheparticular['USO COCHE PARTICULAR'] = df_cocheparticular['USO COCHE PARTICULAR'].astype('Float64')
print(df_cocheparticular['USO COCHE PARTICULAR'].dtype)
df_cocheparticular
# Out:
# object
# Float64
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2362742121.py:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cocheparticular['USO COCHE PARTICULAR'] = df_cocheparticular['USO COCHE PARTICULAR'].str.replace(',','.')
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2362742121.py:7: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_cocheparticular['USO COCHE PARTICULAR'] = df_cocheparticular['USO COCHE PARTICULAR'].astype('Float64')
#                  DISTRITO  USO COCHE PARTICULAR
# 0                  Centro                  43.3
# 1              Arganzuela                  45.0
# 2                  Retiro                  42.0
# 3               Salamanca                  41.7
# 4               Chamartín                  41.8
# 5                  Tetuán                  39.9
# 6                Chamberí                  37.2
# 7   Fuencarral - El Pardo                  59.0
# 8       Moncloa - Aravaca                  56.3
# 9                  Latina                  44.3
# 10            Carabanchel                  45.5
# 11                  Usera                  50.3
# 12     Puente de Vallecas                  46.2
# 13              Moratalaz                  52.8
# 14          Ciudad Lineal                  51.1
# 15              Hortaleza                  58.3
# 16             Villaverde                  44.0
# 17      Villa de Vallecas                  63.8
# 18              Vicálvaro                  66.8
# 19  San Blas - Canillejas                  60.2
# 20                Barajas                  70.6

# %%
df_datosobjetoestudio = pd.concat([df_datosobjetoestudio, df_cocheparticular['USO COCHE PARTICULAR']], axis=1)
df_datosobjetoestudio
# Out:
#                 DISTRITO  NUM_PERSONAS  DENSIDAD_POR_KM2  \
# 0                 Centro       139.687          25340.69
# 1             Arganzuela       153.304          23306.44
# 2                 Retiro       117.918          21867.53
# 3              Salamanca       145.702          26830.78
# 4              Chamartín       144.796          15723.25
# 5                 Tetuán       160.002          28664.25
# 6               Chamberí       138.204          29049.26
# 7    Fuencarral-El Pardo       248.443           1003.00
# 8        Moncloa-Aravaca       121.757           2515.26
# 9                 Latina       241.672           9183.75
# 10           Carabanchel       262.339          17316.88
# 11                 Usera       142.746          17535.32
# 12    Puente de Vallecas       241.603          15345.01
# 13             Moratalaz        92.814          15493.59
# 14         Ciudad Lineal       220.345          18455.56
# 15             Hortaleza       198.391           6973.33
# 16            Villaverde       159.038           7059.13
# 17     Villa de Vallecas       117.501           2026.82
# 18             Vicálvaro        83.804           1981.11
# 19   San Blas-Canillejas       161.219           6934.37
# 20               Barajas        48.646           1076.06
#
#     RENTA BRUTA MEDIA POR PERSONA  RENTA BRUTA MEDIA POR HOGAR  \
# 0                          27.030                       53.908
# 1                          27.431                       63.160
# 2                          33.396                       79.868
# 3                          38.751                       89.407
# 4                          42.678                      104.706
# 5                          22.890                       53.816
# 6                          36.934                       81.889
# 7                          28.798                       76.386
# 8                          36.592                       93.541
# 9                          17.267                       42.843
# 10                         15.239                       40.339
# 11                         13.481                       37.737
# 12                         13.354                       35.380
# 13                         20.091                       49.289
# 14                         22.440                       55.112
# 15                         29.047                       76.741
# 16                         13.604                       38.269
# 17                         17.346                       44.960
# 18                         18.214                       48.513
# 19                         19.768                       51.558
# 20                         27.125                       70.909
#
#     ha de ZONAS VERDES Y PARQUES  TOTAL_VEHICULOS  HAB/COCHE  \
# 0                          31.48           60.871       2.29
# 1                          90.71           71.796       2.14
# 2                          37.64           68.691       1.72
# 3                          35.79           88.462       1.65
# 4                          56.41            95.43       1.52
# 5                           63.7           79.078       2.02
# 6                            9.9           75.014       1.84
# 7                         368.19          128.471       1.93
# 8                         187.47           71.289       1.71
# 9                         276.95          103.929       2.33
# 10                        229.76          108.043       2.43
# 11                        167.85           58.056       2.46
# 12                        279.58          102.689       2.35
# 13                        117.81           44.526       2.08
# 14                        133.67          108.636       2.03
# 15                        323.59          102.474       1.94
# 16                        216.11           69.121       2.30
# 17                        309.29           55.886       2.10
# 18                        195.53           38.365       2.18
# 19                        175.02           81.873       1.97
# 20                        101.68           29.415       1.65
#
#     USO COCHE PARTICULAR
# 0                   43.3
# 1                   45.0
# 2                   42.0
# 3                   41.7
# 4                   41.8
# 5                   39.9
# 6                   37.2
# 7                   59.0
# 8                   56.3
# 9                   44.3
# 10                  45.5
# 11                  50.3
# 12                  46.2
# 13                  52.8
# 14                  51.1
# 15                  58.3
# 16                  44.0
# 17                  63.8
# 18                  66.8
# 19                  60.2
# 20                  70.6

# %% [markdown]
# ##### **DATASET 9 - Estaciones de Medición de la Calidad de Aire por Distrito, año 2023**

# %% [markdown]
# Para terminar el preprocesado de datos voy a preparar un pequeño DataFrame que, a partir de dos mapas, refleje la relación que hay entre la ubicación de las Estaciones de Medición de la Calidad de Aire y el Distrito en el que se ubican, dado que de manera oficial las Estaciones de Aire se agrupan por Zonas de Aire.

# %% [markdown]
# **Mapa oficial de Estaciones de Aire de Madrid ciudad** <br>
# Fuente: 'https://datos.madrid.es/portal/site/egob/menuitem.c05c1f754a33a9fbe4b2e4b284f1a5a0/?vgnextoid=9e42c176313eb410VgnVCM1000000b205a0aRCRD&vgnextchannel=374512b9ace9f310VgnVCM100000171f5a0aRCRD'

# %% [markdown]
# ![imagen](./data/mapa_estaciones_aire.jpg)

# %% [markdown]
# **Mapa Red de estaciones de vigilancia de calidad del aire de Madrid ciudad** <br>
# Fuente: 'https://www.madrid.es/portales/munimadrid/es/Inicio/Medio-ambiente/Direcciones-y-telefonos/Red-de-estaciones-fijas-de-control-de-calidad-del-aire/?vgnextfmt=default&vgnextoid=aeca16d591bbf710VgnVCM2000001f4a900aRCRD&vgnextchannel=864f79ed268fe410VgnVCM1000000b205a0aRCRD'

# %% [markdown]
# ![imagen](./data/mapa_red_control_aire.jpg)

# %% [markdown]
# **Mapa Distritos de Madrid** <br>
# Fuente: https://airedemadrid.madrid.es/portales/calidadaire/es/Bases-de-datos-y-publicaciones/Bases-de-datos-de-calidad-del-aire/Indices-y-zonas/Zonas-de-la-ciudad-de-Madrid-a-efectos-de-Calidad-del-Aire/?vgnextfmt=default&vgnextoid=9b63d32e36bd5710VgnVCM1000001d4a900aRCRD&vgnextchannel=480285a1259d7710VgnVCM2000001f4a900aRCRD

# %% [markdown]
# ![imagen](./data/mapa_distritos_madrid_decide.jpg)

# %% [markdown]
# Estudiar la ubicación de las Estaciones de Medición de Calidad de Aire me permite crear el siguiente DataFrame.

# %%
df_dataset9 = pd.read_csv('./data/09_estaciones_aire_madrid_distrito.csv', sep=';', encoding='MacRoman')
df_dataset9 = df_dataset9.sort_values(by='COD_DISTRITO', ascending= True)
df_dataset9.reset_index(drop=True)

df_dataset9 = df_dataset9.sort_values(by='ESTACION', ascending=True)

df_no2_estaciones = pd.merge(df_dataset9, df_no2, on="ESTACION", how="inner")
df_no2_estaciones = df_no2_estaciones.sort_values(by='COD_DISTRITO', ascending= True)
df_no2_estaciones = df_no2_estaciones.reset_index(drop=True)
df_no2_estaciones
# Out:
#     COD_DISTRITO               DISTRITO              ESTACION    CODIGO  \
# 0              1                 Centro      Plaza del Carmen  28079035
# 1              1                 Centro       Plaza de España  28079004
# 2              2             Arganzuela         Méndez Álvaro  28079047
# 3              3                 Retiro      Escuelas Aguirre  28079008
# 4              3                 Retiro     Parque del Retiro  28079049
# 5              4              Salamanca            Castellana  28079048
# 6              5              Chamartín        Plaza Castilla  28079050
# 7              5              Chamartín         Ramón y Cajal  28079011
# 8              6                 Tetuán        Cuatro Caminos  28079038
# 9              8  Fuencarral - El Pardo           Tres Olivos  28079060
# 10             8  Fuencarral - El Pardo      Barrio del Pilar  28079039
# 11             8  Fuencarral - El Pardo              El Pardo  28079058
# 12             9      Moncloa - Aravaca         Casa de Campo  28079024
# 13            11            Carabanchel             Farolillo  28079018
# 14            12            Carabanchel        Plaza Elíptica  28079056
# 15            13     Puente de Vallecas              Vallecas  28079040
# 16            14              Moratalaz             Moratalaz  28079036
# 17            15          Ciudad Lineal          Arturo Soria  28079016
# 18            16              Hortaleza           Sanchinarro  28079057
# 19            17             Villaverde            Villaverde  28079017
# 20            18      Villa de Vallecas  Ensanche de Vallecas  28079054
# 21            21                Barajas        Barajas Pueblo  28079027
# 22            21                Barajas         Juan Carlos I  28079059
# 23            21                Barajas         Urb. Embajada  28079055
#
#                                             DIRECCION        NOM_TIPO  \
# 0                   Plaza del Carmen esq. Tres Cruces    Urbana fondo
# 1                                     Plaza de España  Urbana tráfico
# 2   C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    Urbana fondo
# 3                      Entre C/ Alcalá y C/ O’ Donell  Urbana tráfico
# 4               Paseo Venezuela- Palacio de Velázquez    Urbana fondo
# 5                           C/ José Gutiérrez Abascal  Urbana tráfico
# 6                              Plaza Castilla (Canal)  Urbana tráfico
# 7     Avda. Ramón y Cajal esq. C/ Príncipe de Vergara  Urbana tráfico
# 8        Avda. Pablo Iglesias esq. C/ Marqués de Lema  Urbana tráfico
# 9                                   Plaza Tres Olivos    Urbana fondo
# 10           Avda. Betanzos esq. C/ Monforte de Lemos  Urbana tráfico
# 11                                   Avda. La Guardia       Suburbana
# 12            Casa de Campo (Terminal del Teleférico)       Suburbana
# 13                          C/ Farolillo - C/ Ervigio    Urbana fondo
# 14                      Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 15           C/ Arroyo del Olivar esq. C/ Río Grande.    Urbana fondo
# 16       Avda. Moratalaz esq. Camino de los Vinateros  Urbana tráfico
# 17     C/ Arturo Soria esq. C/ Vizconde de los Asilos    Urbana fondo
# 18           C/ Princesa de Éboli esq. C/ María Tudor    Urbana fondo
# 19                                   C/ Juan Peñalver    Urbana fondo
# 20                 Avda. La Gavia / Avda. Las Suertes    Urbana fondo
# 21                                     C/ Júpiter, 21    Urbana fondo
# 22  Parque Juan Carlos I (frente oficinas mantenim...       Suburbana
# 23                                 C/ Riaño (Barajas)    Urbana fondo
#
#     CONCENTRACIONES MAXIMAS HORARIAS
# 0                                130
# 1                                156
# 2                                140
# 3                                175
# 4                                131
# 5                                162
# 6                                166
# 7                                183
# 8                                167
# 9                                135
# 10                               186
# 11                                86
# 12                                98
# 13                               149
# 14                               195
# 15                               147
# 16                               139
# 17                               177
# 18                               186
# 19                               196
# 20                               194
# 21                               163
# 22                               137
# 23                               171

# %% [markdown]
# **Consideraciones relevantes:**
#
# Los distritos de Madrid ciudad que de manera directa no cuentan con una Estación de Medición de Calidad del Aire son:
# - Distrito 7 Chamberí.
# - Distrito 10 Latina.
# - Distrito 12 Usera.
# - Distrito 19 Vicálvaro.
# - Distrito 20 San Blas - Canillejas.
#
#
# Voy a asignar de manera totalmente consciente la Estación Plaza Elíptica al Distrito 12 Usera porque, aunque se encuentra en el Distrito 11 Carabanchel, se encuentra a una sola manzana de formar parte de Usera. Se ubica en Plaza Elíptica, popular plaza con una parte que se enmarca en Carabanchel y otra situada en Usera.
#
# - Las Estaciones de Castellana y Cuatro Caminos están próximas a Distrito 7 Chamberí.
#
# - Las Estaciones de Plaza de España y Farolillo están cerca del Distrito 10 Latina.
#
# - Las Estaciones de Moratalaz y Ensanche de Vallecas son equidistantes al Distrito 19 Vicálvaro.
#
# - La Estación de Arturo Soria está relativamente cerca del Distrito 20 San Blas - Canillejas, la de Moratalaz algo más alejada.
#
# Teniendo en cuenta las premisas explicadas, voy a dar un valor al Dióxido de Nitrógeno de los Distritos que carecen de Estación, para ello asignaré el valor medio correspondiente a las dos estaciones más próximas. <br>
#
# Para aquellos distritos con dos o más estaciones de medición me quedaré con una media de los valores de dióxido de nitrógeno registrados por las diferentes estaciones.

# %%
# Compruebo el tipo de dato que contiene la columna 'CONCENTRACIONES MAXIMAS HORARIAS'
print(df_no2_estaciones['CONCENTRACIONES MAXIMAS HORARIAS'].dtype)
# Valor para Distrito 7 Chamberí
no2_d7 = (162+167)/2
print(no2_d7)
# Valor para Distrito 10 Latina
no2_d10 = (156+149)/2
print(no2_d10)
# Valor para Distrito 19 Vicálvaro
no2_d19 = (139+194)/2
print(no2_d19)
# Valor para Distrito 20 San Blas - Canillejas
no2_d20 = (177+139)/2
print(no2_d20)
# Out:
# int64
# 164.5
# 152.5
# 166.5
# 158.0

# %%
# Valor para Distrito 1 Centro
no2_d1 = (130+156)/2
print(no2_d1)
# Valor para Distrito 3 Retiro
no2_d3 = (175+131)/2
print(no2_d3)
# Valor para Distrito 5 Chamartín
no2_d5 = (166+183)/2
print(no2_d5)
# Valor para Distrito 8 Fuencarral - El Pardo
no2_d8 = (135+186+86)/3
print(no2_d8)
# Valor para Distrito 11 Carabanchel
no2_d11 = (149+195)/2
print(no2_d11)
# Valor para Distrito 21 Barajas
no2_d21 = (163+137+171)/3
print(no2_d21)
# Out:
# 143.0
# 153.0
# 174.5
# 135.66666666666666
# 172.0
# 157.0

# %% [markdown]
# En función de estos cálculos, y apoyándome en Excel, obtengo las siguientes dos tablas.

# %%
df_no2_estacionesydistritos = pd.read_csv('./data/09_no2_distritosyestaciones.csv', sep=';', encoding='MacRoman')
df_no2_estacionesydistritos
# Out:
#     COD_DISTRITO               DISTRITO              ESTACION      CODIGO  \
# 0              1                 Centro      Plaza del Carmen  28079035.0
# 1              1                 Centro       Plaza de España  28079004.0
# 2              2             Arganzuela         Méndez Álvaro  28079047.0
# 3              3                 Retiro      Escuelas Aguirre  28079008.0
# 4              3                 Retiro     Parque del Retiro  28079049.0
# 5              4              Salamanca            Castellana  28079048.0
# 6              5              Chamartín        Plaza Castilla  28079050.0
# 7              5              Chamartín         Ramón y Cajal  28079011.0
# 8              6                 Tetuán        Cuatro Caminos  28079038.0
# 9              7               Chamberí                   NaN         NaN
# 10             8  Fuencarral - El Pardo           Tres Olivos  28079060.0
# 11             8  Fuencarral - El Pardo      Barrio del Pilar  28079039.0
# 12             8  Fuencarral - El Pardo              El Pardo  28079058.0
# 13             9      Moncloa - Aravaca         Casa de Campo  28079024.0
# 14            10                 Latina                   NaN         NaN
# 15            11            Carabanchel             Farolillo  28079018.0
# 16            12            Carabanchel        Plaza Elíptica  28079056.0
# 17            12                  Usera        Plaza Elíptica  28079056.0
# 18            13     Puente de Vallecas              Vallecas  28079040.0
# 19            14              Moratalaz             Moratalaz  28079036.0
# 20            15          Ciudad Lineal          Arturo Soria  28079016.0
# 21            16              Hortaleza           Sanchinarro  28079057.0
# 22            17             Villaverde            Villaverde  28079017.0
# 23            18      Villa de Vallecas  Ensanche de Vallecas  28079054.0
# 24            19              Vicálvaro                   NaN         NaN
# 25            20  San Blas - Canillejas                   NaN         NaN
# 26            21                Barajas        Barajas Pueblo  28079027.0
# 27            21                Barajas         Juan Carlos I  28079059.0
# 28            21                Barajas         Urb. Embajada  28079055.0
#
#                                             DIRECCION        NOM_TIPO  \
# 0                   Plaza del Carmen esq. Tres Cruces    Urbana fondo
# 1                                     Plaza de España  Urbana tráfico
# 2   C/ Juan de Mariana / Plaza Amanecer Méndez Álvaro    Urbana fondo
# 3                      Entre C/ Alcalá y C/ O’ Donell  Urbana tráfico
# 4               Paseo Venezuela- Palacio de Velázquez    Urbana fondo
# 5                           C/ José Gutiérrez Abascal  Urbana tráfico
# 6                              Plaza Castilla (Canal)  Urbana tráfico
# 7     Avda. Ramón y Cajal esq. C/ Príncipe de Vergara  Urbana tráfico
# 8        Avda. Pablo Iglesias esq. C/ Marqués de Lema  Urbana tráfico
# 9                                                 NaN             NaN
# 10                                  Plaza Tres Olivos    Urbana fondo
# 11           Avda. Betanzos esq. C/ Monforte de Lemos  Urbana tráfico
# 12                                   Avda. La Guardia       Suburbana
# 13            Casa de Campo (Terminal del Teleférico)       Suburbana
# 14                                                NaN             NaN
# 15                          C/ Farolillo - C/ Ervigio    Urbana fondo
# 16                      Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 17                      Plaza Elíptica - Avda. Oporto  Urbana tráfico
# 18           C/ Arroyo del Olivar esq. C/ Río Grande.    Urbana fondo
# 19       Avda. Moratalaz esq. Camino de los Vinateros  Urbana tráfico
# 20     C/ Arturo Soria esq. C/ Vizconde de los Asilos    Urbana fondo
# 21           C/ Princesa de Éboli esq. C/ María Tudor    Urbana fondo
# 22                                   C/ Juan Peñalver    Urbana fondo
# 23                 Avda. La Gavia / Avda. Las Suertes    Urbana fondo
# 24                                                NaN             NaN
# 25                                                NaN             NaN
# 26                                     C/ Júpiter, 21    Urbana fondo
# 27  Parque Juan Carlos I (frente oficinas mantenim...       Suburbana
# 28                                 C/ Riaño (Barajas)    Urbana fondo
#
#     CONCENTRACIONES MAXIMAS HORARIAS
# 0                                130
# 1                                156
# 2                                140
# 3                                175
# 4                                131
# 5                                162
# 6                                166
# 7                                183
# 8                                167
# 9                                165
# 10                               135
# 11                               186
# 12                                86
# 13                                98
# 14                               153
# 15                               149
# 16                               195
# 17                               195
# 18                               147
# 19                               139
# 20                               177
# 21                               186
# 22                               196
# 23                               194
# 24                               167
# 25                               158
# 26                               163
# 27                               137
# 28                               171

# %%
df_no2_distritos = pd.read_csv('./data/09_no2_distritos.csv', sep=';', encoding='MacRoman')
df_no2_distritos
# Out:
#                  DISTRITO  NO2
# 0                  Centro  143
# 1              Arganzuela  140
# 2                  Retiro  153
# 3               Salamanca  162
# 4               Chamartín  175
# 5                  Tetuán  167
# 6                Chamberí  165
# 7   Fuencarral - El Pardo  136
# 8       Moncloa - Aravaca   98
# 9                  Latina  153
# 10            Carabanchel  172
# 11                  Usera  195
# 12     Puente de Vallecas  147
# 13              Moratalaz  139
# 14          Ciudad Lineal  177
# 15              Hortaleza  186
# 16             Villaverde  196
# 17      Villa de Vallecas  194
# 18              Vicálvaro  167
# 19  San Blas - Canillejas  158
# 20                Barajas  157

# %%
df_datosobjetoestudio = pd.concat([df_datosobjetoestudio, df_no2_distritos['NO2']], axis=1)
df_datosobjetoestudio.columns = df_datosobjetoestudio.columns.str.replace('NUM_PERSONAS','HABITANTES')
df_datosobjetoestudio.columns = df_datosobjetoestudio.columns.str.replace('DENSIDAD_POR_KM2','DENSIDAD POR KM2')
df_datosobjetoestudio.columns = df_datosobjetoestudio.columns.str.replace('TOTAL_VEHICULOS','TOTAL VEHICULOS')
df_datosobjetoestudio
# Out:
#                 DISTRITO  HABITANTES  DENSIDAD POR KM2  \
# 0                 Centro     139.687          25340.69
# 1             Arganzuela     153.304          23306.44
# 2                 Retiro     117.918          21867.53
# 3              Salamanca     145.702          26830.78
# 4              Chamartín     144.796          15723.25
# 5                 Tetuán     160.002          28664.25
# 6               Chamberí     138.204          29049.26
# 7    Fuencarral-El Pardo     248.443           1003.00
# 8        Moncloa-Aravaca     121.757           2515.26
# 9                 Latina     241.672           9183.75
# 10           Carabanchel     262.339          17316.88
# 11                 Usera     142.746          17535.32
# 12    Puente de Vallecas     241.603          15345.01
# 13             Moratalaz      92.814          15493.59
# 14         Ciudad Lineal     220.345          18455.56
# 15             Hortaleza     198.391           6973.33
# 16            Villaverde     159.038           7059.13
# 17     Villa de Vallecas     117.501           2026.82
# 18             Vicálvaro      83.804           1981.11
# 19   San Blas-Canillejas     161.219           6934.37
# 20               Barajas      48.646           1076.06
#
#     RENTA BRUTA MEDIA POR PERSONA  RENTA BRUTA MEDIA POR HOGAR  \
# 0                          27.030                       53.908
# 1                          27.431                       63.160
# 2                          33.396                       79.868
# 3                          38.751                       89.407
# 4                          42.678                      104.706
# 5                          22.890                       53.816
# 6                          36.934                       81.889
# 7                          28.798                       76.386
# 8                          36.592                       93.541
# 9                          17.267                       42.843
# 10                         15.239                       40.339
# 11                         13.481                       37.737
# 12                         13.354                       35.380
# 13                         20.091                       49.289
# 14                         22.440                       55.112
# 15                         29.047                       76.741
# 16                         13.604                       38.269
# 17                         17.346                       44.960
# 18                         18.214                       48.513
# 19                         19.768                       51.558
# 20                         27.125                       70.909
#
#     ha de ZONAS VERDES Y PARQUES  TOTAL VEHICULOS  HAB/COCHE  \
# 0                          31.48           60.871       2.29
# 1                          90.71           71.796       2.14
# 2                          37.64           68.691       1.72
# 3                          35.79           88.462       1.65
# 4                          56.41            95.43       1.52
# 5                           63.7           79.078       2.02
# 6                            9.9           75.014       1.84
# 7                         368.19          128.471       1.93
# 8                         187.47           71.289       1.71
# 9                         276.95          103.929       2.33
# 10                        229.76          108.043       2.43
# 11                        167.85           58.056       2.46
# 12                        279.58          102.689       2.35
# 13                        117.81           44.526       2.08
# 14                        133.67          108.636       2.03
# 15                        323.59          102.474       1.94
# 16                        216.11           69.121       2.30
# 17                        309.29           55.886       2.10
# 18                        195.53           38.365       2.18
# 19                        175.02           81.873       1.97
# 20                        101.68           29.415       1.65
#
#     USO COCHE PARTICULAR  NO2
# 0                   43.3  143
# 1                   45.0  140
# 2                   42.0  153
# 3                   41.7  162
# 4                   41.8  175
# 5                   39.9  167
# 6                   37.2  165
# 7                   59.0  136
# 8                   56.3   98
# 9                   44.3  153
# 10                  45.5  172
# 11                  50.3  195
# 12                  46.2  147
# 13                  52.8  139
# 14                  51.1  177
# 15                  58.3  186
# 16                  44.0  196
# 17                  63.8  194
# 18                  66.8  167
# 19                  60.2  158
# 20                  70.6  157

# %% [markdown]
# #### **GRÁFICOS**
#
# Teniendo en cuenta mis hipótesis, necesito el siguiente material:
#
# 1. Mapa ubicación de Estaciones de Medición de Calidad de Aire y tabla explicativa por Distrito.
# 2. Diagrama de barras para el Dióxido de Nitrógeno (NO2) por Estación.
# 3. Calcular y representar correlación entre la renta bruta media por persona y la renta bruta media por hogar.
# 4. Diagrama de barras para la Renta Bruta Media por Persona.
# 5. Diagrama de barras para la Densidad de Población por Kilómetros Cuadrados (KM2).
# 6. Diagrama de barras para la Superficie de Zonas Verdes y Parques.
# 7. Diagrama de barras para el Total de Vehículos.
# 8. Diagrama de barras para el Uso de Coche Particular.
# 9. Diagrama de barras para el Dióxido de Nitrógeno (NO2) por Distrito.
# 10. Heatmap para Variables Objeto de Estudio.

# %%
# Importo los módulos que podría necesitar 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %% [markdown]
# ##### **GRÁFICO 1: Mapa ubicación de Estaciones de Medición de Calidad de Aire por Distrito** <br>
#
# **Mapa oficial de Estaciones de Aire de Madrid ciudad** <br>
# ![imagen](./data/mapa_estaciones_aire.jpg)
#
# **Tabla Estaciones de Calidad del Aire por distrito** <br>
# ![imagen](./data/01-tabla_estaciones_por_distrito.png)

# %% [markdown]
# Viendo esta tabla se aprecia que existe al menos una Estación de Medición del Calidad de Aire en 16 de los 21 distritos de Madrid ciudad. Los distritos en los que no encontramos una Estación física de Medición son: Chamberí (Distrito 7), Latina (Distrito 10), Usera (Distrito 12), Vicálvaro (Distrito 19) y San Blas - Canillejas (Distrito 20).

# %% [markdown]
# ##### **GRÁFICO 2: Diagrama de barras para el DataFrame 'Dióxido de Nitrógeno' (NO2) por Estación** <br>

# %%
# Ordeno el DataFrame por 'CONCENTRACIONES MAXIMAS HORARIAS' en orden descendente
df_no2_sorted = df_no2.sort_values(by="CONCENTRACIONES MAXIMAS HORARIAS", ascending=False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid") 

# Creo el gráfico de barras con Seaborn
ax = sns.barplot(
    data=df_no2_sorted,
    x="ESTACION",
    y="CONCENTRACIONES MAXIMAS HORARIAS",
    palette="Oranges_r"
)

# Añado etiquetas y título
ax.set_title("CONCENTRACIONES MÁXIMAS HORARIAS DE NO2", fontsize=16)
ax.set_xlabel("")
ax.set_ylabel("Concentración Máxima Horaria (µg/m³)", fontsize=12)
ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=10, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2187709757.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   ax = sns.barplot(
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2187709757.py:20: UserWarning: set_ticklabels() should only be used with a fixed number of ticks, i.e. after set_ticks() or using a FixedLocator.
#   ax.set_xticklabels(ax.get_xticklabels(), rotation=45, fontsize=10, ha='right')

# %% [markdown]
# - Las Estaciones que registran una **mayor concentración de NO2** son: **VILLAVERDE**, Plaza Elíptica, Ensanche de Vallecas, Barrio del Pilar y Sanchinarro.
# - Las Estaciones que registran una **menor concentración de NO2** son: **EL PARDO**, Casa de Campo, Plaza del Carmen, Parque del Retiro y Tres Olivos.

# %% [markdown]
# ##### **GRÁFICO 3: Calcular y representar correlación entre Renta Bruta Media y Renta Bruta Media por Hogar.** <br>

# %%
# Calculo la correlación entre los dos tipos de renta para predecir el valor de una variable en función de la otra
correlation = df_rentas[['RENTA BRUTA MEDIA POR PERSONA', 'RENTA BRUTA MEDIA POR HOGAR']].corr()
print(correlation)
print("\nLa correlación entre 'Renta Bruta Media por Persona' y 'Renta Bruta Media por Hogar' es muy alta")

# Configuro el gráfico
plt.figure(figsize=(10, 6))
sns.set_theme(style="whitegrid")

# Grafico de dispersión con línea de regresión
sns.regplot(
    data=df_rentas,
    x="RENTA BRUTA MEDIA POR PERSONA",
    y="RENTA BRUTA MEDIA POR HOGAR",
    scatter_kws={'alpha': 0.6},
    line_kws={'color': 'red'}
)

# Etiquetas y título
plt.title("RELACIÓN ENTRE RENTA BRUTA MEDIA POR PERSONA Y POR HOGAR", fontsize=14)
plt.xlabel("Renta Bruta Media por Persona", fontsize=12)
plt.ylabel("Renta Bruta Media por Hogar", fontsize=12)

plt.tight_layout()
plt.show()
# Out:
#                                RENTA BRUTA MEDIA POR PERSONA  \
# RENTA BRUTA MEDIA POR PERSONA                        1.00000
# RENTA BRUTA MEDIA POR HOGAR                          0.97649
#
#                                RENTA BRUTA MEDIA POR HOGAR
# RENTA BRUTA MEDIA POR PERSONA                      0.97649
# RENTA BRUTA MEDIA POR HOGAR                        1.00000
#
# La correlación entre 'Renta Bruta Media por Persona' y 'Renta Bruta Media por Hogar' es muy alta

# %% [markdown]
# ##### **GRÁFICO 4: Diagrama de barras para la Renta Bruta Media por Persona** <br>

# %%
# Ordeno el DataFrame en función de la columna 'RENTA BRUTA MEDIA POR PERSONA' en orden descendente
df_sorted = df_rentas.sort_values(by="RENTA BRUTA MEDIA POR PERSONA", ascending=False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))

# Creo el diagrama de barras
plt.bar(
    x=df_sorted["DISTRITO"], 
    height=df_sorted["RENTA BRUTA MEDIA POR PERSONA"],  
    color="skyblue",  
    alpha=0.8  
)

# Añado etiquetas y título
plt.title("RENTA BRUTA MEDIA POR PERSONA", fontsize=16)
plt.xlabel("")
plt.ylabel("Renta Bruta Media por Persona (en 1000€)", fontsize=12)
plt.xticks(rotation=45, fontsize=10, ha='right')

plt.tight_layout()
plt.show()

# %% [markdown]
# - Las Distritos que registran una **mayor Renta Bruta Media por Persona** son: **CHAMARTÍN**, Salamanca, Chamberí, Moncloa-Aravaca, Retiro.
# - Los Distritos que registran una **menor Renta Bruta Media por Persona** son: **PUENTE DE VALLECAS**, Usera, Villaverde, Carabanchel, Latina.

# %% [markdown]
# ##### **GRÁFICO 5: Diagrama de barras para la Densidad de Población por Kilómetros Cuadrados (KM2) en cada Distrito** <br>

# %%
# Ordeno el DataFrame en función de la densidad de población en orden descendente
df_sorted = df_densidadpoblacion.sort_values(by="DENSIDAD_POR_KM2", ascending=False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid")

# Creo el gráfico de barras
sns.barplot(
    data=df_sorted,
    x="DISTRITO",  
    y="DENSIDAD_POR_KM2",  
    palette="magma"  
)

# Añado etiquetas y título
plt.title("DENSIDAD DE POBLACIÓN POR DISTRITO", fontsize=16)
plt.xlabel("")
plt.ylabel("Densidad de Población (hab/km²)", fontsize=12)
plt.xticks(rotation=45, fontsize=10, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/4201106923.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# - Las Distritos que registran una **mayor densidad de población por KM2** son: **CHAMBERÍ**, Tetuán, Salamanca, Centro, Arganzuela.
# - Los Distritos que registran una **menor densidad de población por KM2** son: **FUENCARRAL-EL PARDO**, Barajas, Vicálvaro, Villa de Vallecas y Moncloa-Aravaca.

# %% [markdown]
# ##### **GRÁFICO 6: Diagrama de barras para la Superficie de Zonas Verdes y Parques por Distrito** <br>

# %%
# Ordeno el DataFrame en función de la densidad de población en orden descendente
df_sorted = df_parqueszonasverdes.sort_values(by="ha de ZONAS VERDES Y PARQUES", ascending=False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid")
colors = sns.light_palette("seagreen", n_colors=len(df_sorted))[::-1]

# Creo el gráfico de barras
sns.barplot(
    data=df_sorted,
    x="DISTRITO",  
    y="ha de ZONAS VERDES Y PARQUES",  
    palette=colors  
)

# Añado etiquetas y título
plt.title("SUPERFICIE DE ZONAS VERDES Y PARQUES", fontsize=16)
plt.xlabel("")
plt.ylabel("Superficie por hectáreas (ha)", fontsize=12)
plt.xticks(rotation=45, fontsize=10, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/1677608263.py:10: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# - Los Distritos que registran una **mayor Superficie en hectáreas (ha) de Zonas Verdes y Parques** son: **FUENCARRAL-ELPARDO**, Hortaleza, Villa de Vallecas, Puente de Vallecas y Latina.
# - Los Distritos que registran una **menor Superficie en hectáreas (ha) de Zonas Verdes y Parques** son: **CHAMBERÍ**, Centro, Salamanca, Retiro y Chamartín.

# %% [markdown]
# ##### **GRÁFICO 7: Diagrama de barras para el Total de Vehículos por Distrito** <br>

# %%
df_habitantesyvehiculo_grafico = df_habitantesyvehiculo
df_habitantesyvehiculo_grafico = df_habitantesyvehiculo_grafico.drop('TOTAL_VEHICULOS', axis=1)

# Ordeno el DataFrame en función del TOTAL_VEHÍCULOS en orden descendente
df_sorted = df_habitantesyvehiculo_grafico.sort_values(by="HAB/COCHE", ascending= False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))

# Datos para el gráfico
x = df_sorted["DISTRITO"]
y = df_sorted["HAB/COCHE"]

# Creo las barras
plt.bar(x, y, color="dimgray")

# Personalizo etiquetas y título
plt.title("HABITANTES POR VEHÍCULO EN DISTRITOS", fontsize=16)
plt.xlabel("")
plt.ylabel("Habitantes / Vehículos", fontsize=10)
plt.xticks(rotation=45, fontsize=10, ha='right') 

plt.tight_layout()
plt.show()

# %% [markdown]
# - Los Distritos que registran un **mayor Número de Habitantes / Número de Coches** son: **USERA**, Carabanchel, Puente de Vallecas, Latina y Villaverde.
# - Los Distritos que registran un **menor Número de Habitantes / Número de Coches** son: **CHAMARTÍN**, Salamanca, Barajas, Moncloa-Aravaca y Retiro.

# %% [markdown]
# ##### **GRÁFICO 8: Diagrama de barras para el Uso del Coche Particular por Distrito** <br>

# %%
# Ordeno el DataFrame en función del TOTAL_VEHÍCULOS en orden descendente
df_sorted = df_cocheparticular.sort_values(by="USO COCHE PARTICULAR", ascending= False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))

# Datos para el gráfico
x = df_sorted["DISTRITO"]
y = df_sorted["USO COCHE PARTICULAR"]

# Creo las barras
plt.bar(x, y, color="saddlebrown")

# Personalizo etiquetas y título
plt.title("USO DEL COCHE PARTICULAR POR DISTRITO", fontsize=16)
plt.xlabel("")
plt.ylabel("% USO", fontsize=10)
plt.xticks(rotation=45, fontsize=10, ha='right') 

plt.tight_layout()
plt.show()

# %% [markdown]
# - Los Distritos que registran un **mayor Uso del Coche Particular** son: **BARAJAS**, Vicálvaro, Villa de Vallecas, San Blas-Canillejas y Fuencarral-El Pardo.
# - Los Distritos que registran un **menor Uso del Coche Particular** son: **CHAMBERÍ**, Tetuán, Salamanca, Chamartín y Retiro.

# %% [markdown]
# ##### **GRÁFICO 9: Diagrama de barras para el Dióxido de Nitrógeno (NO2) por Distrito** <br>

# %%
# Ordeno el DataFrame en función de la densidad de población en orden descendente
df_sorted = df_no2_distritos.sort_values(by="NO2", ascending=False)

# Configuro el gráfico
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid")

# Creo el gráfico de barras
sns.barplot(
    data=df_sorted,
    x="DISTRITO",  
    y="NO2",  
    palette="Oranges_r"  
)

# Añado etiquetas y título
plt.title("DIÓXIDO DE NITRÓGENO (N02) POR DISTRITO", fontsize=16)
plt.xlabel("")
plt.ylabel("Concentración Máxima Horaria (µg/m³)", fontsize=12)
plt.xticks(rotation=45, fontsize=10, ha='right')

plt.tight_layout()
plt.show()
# Out:
# /var/folders/m4/4mx3075j6459pp9gm5pk4tsc0000gn/T/ipykernel_4248/2590460991.py:9: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `x` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.barplot(

# %% [markdown]
# - Los Distritos que registran una **mayor Concentración de Dióxido de Nitrógeno (NO2)** son: **VILLAVERDE**, Usera, Villa de Vallecas, Hortaleza y Ciudad Lineal.
# - Los Distritos que registran una **menor Concentración de Dióxido de Nitrógeno (NO2)** son: **MONCLOA-ARAVACA**, Fuencarral-El Pardo, Moratalaz, Arganzuela y Centro.

# %% [markdown]
# ##### **GRÁFICO 10: Heatmap para Variables Objeto de Estudio** <br>
#
# Un heatpmap es muy buena herramienta para confirmar posibles correlaciones entre todas las variables numéricas implicadas en un Análisis de Datos. Esta interdependencia se verifica atendiendo al valor obtenido, que nos permitirá hablar de los siguientes tipos de correlaciones:
# - Correlaciones cercanas a 1: relación positiva fuerte. El incremento de una variable repercute en el aumento de otra o, en sentido contrario, la disminución de una variable implica el descenso de otra.
# - Correlaciones cercanas a -1: relación negativa fuerte. El incremento de una variable conlleva la bajada de otra y viceversa, la disminución de una variable trae consigo la subida de otra.
# - Correlaciones cercanas a 0: poca o ninguna relación.

# %%
# Cambio el nombre de la columna 'Densidad por KM2' para mejorar la interpretación de datos fuera de contexto
df_datosobjetoestudio.columns = df_datosobjetoestudio.columns.str.replace('DENSIDAD POR KM2', 'DENSIDAD DE POBLACIÓN')

# Selecciono sólo las columnas numéricas
df_estudionumerico = df_datosobjetoestudio.select_dtypes(include='number')

# Calculo la matriz de correlación
correlation_matrix = df_estudionumerico.corr()

# Configuro el gráfico
plt.figure(figsize=(14, 8))
sns.set_theme(style="whitegrid")

# Creo el heatmap
sns.heatmap(correlation_matrix, annot=True, fmt=".2f", cmap="coolwarm", vmin=-1, vmax=1, center=0, linewidths=1)
plt.title("")
plt.tight_layout()

plt.show()

# %% [markdown]
# **Correlaciones Positivas** (cercanas a 1): Número de Personas & Total Vehículo, Renta Bruta Media por Persona & Renta Bruta Media por Hogar. <br>
#
# **Correlaciones Negativas** (cercanas a -1): Densidad de Población & Uso Coche Particular, Densidad de Población & hectáreas de Zonas Verdes y Parques, Renta Bruta Media por Persona & Hab/Coche, Renta Bruta Media por Hogar & Hab/Coche <br>
#
# **Correlaciones Cercanas a 0**: Habitantes & Densidad de Población, Habitantes & NO2, Densidad de Población & Renta Bruta Media por Hogar, Densidad de Población & Total Vehículos, Densidad de Población & Hab/Coche, Densidad de Población & NO2, Renta Bruta Media por Hogar & Uso Coche Particular, Hab/Coche & Uso Coche Particular, Uso Coche Particular & NO2.

# %% [markdown]
# #### **VALIDACIÓN DE MIS HIPÓTESIS ORIGINALES** <br>

# %% [markdown]
# **EN LOS DISTRITOS CON RENTAS MÁS ALTAS DE MADRID CIUDAD LA CALIDAD DEL AIRE ES PEOR.** <br>
# Esta hipótesis es **FALSA**.
# - Las Distritos que registran una **mayor Renta Bruta Media por Persona** son: Chamartín, Salamanca, Chamberí, Moncloa-Aravaca, Retiro. <br>
# - Los Distritos que registran una **mayor Concentración de Dióxido de Nitrógeno (NO2)** son: Villaverde, Usera, Villa de Vallecas, Hortaleza y Ciudad Lineal. <br>
# - 0 coincidencias. <br>
#
# **A MAYOR DENSIDAD DE POBLACIÓN, PEOR ES LA CALIDAD DEL AIRE.** <br>
# Esta hipótesis es **FALSA**.
# - Las Distritos que registran una **mayor densidad de población por KM2** son: Chamberí, Tetuán, Salamanca, Centro y Arganzuela.
# - Los Distritos que registran una **mayor Concentración de Dióxido de Nitrógeno (NO2)** son: Villaverde, Usera, Villa de Vallecas, Fuencarral-El Pardo y Hortaleza. <br>
# - 0 coincidencias. <br>
#
# **LOS HÁBITOS DE MOVILIDAD DE LA POBLACIÓN DE UN DISTRITO PUEDEN FAVORECER O PERJUDICAR LA CALIDAD DEL AIRE.** <br>
# Atendiendo a los datos recopilados la influencia es baja, por lo que podríamos hablar de que la hipótesis es **FALSA**.
#
# - Los Distritos que registran un **mayor Uso del Coche Particular** son: Barajas, Vicálvaro, Villa de Vallecas, San Blas-Canillejas y Fuencarral-El Pardo. <br>
# - Los Distritos que registran una **mayor Concentración de Dióxido de Nitrógeno (NO2)** son: Villaverde, Usera, Villa de Vallecas, Hortaleza y Ciudad Lineal. <br>
# - 1 coincidencia. <br>
#
# **A MAYOR EXTENSIÓN DE ZONAS VERDES EN EL DISTRITO, MEJOR CALIDAD DEL AIRE** <br>
# Dependiendo del enfoque del análisis encuentro dos posibles respuestas. <br>
#
# Si tengo en cuenta la ubicación y medición de las diferentes Estaciones, se podría decir que es **VERDADERA** porque las dos estaciones con menor concentración de NO2 son de tipo 'Suburbana', beneficiadas en ambos casos por zonas verdes de amplia extensión como son El Pardo y la Casa de Campo. La única estación de tipo 'Suburbana' que no hace podio es la de Juan Carlos I por su proximidad al Aeropuerto de Adolfo Suárez Madrid - Barajas. <br>
#
# Si atiendo única y exclusivamente a los valores de NO2 por Distrito mi hipótesis sería **FALSA**:
# - Los Distritos que registran una **mayor Superficie en hectáreas (ha) de Zonas Verdes y Parques** son: Fuencarral-El Pardo, Hortaleza, Villa de Vallecas, Puente de Vallecas y Latina. <br>
# - Los Distritos que registran una **menor Concentración de Dióxido de Nitrógeno (NO2)** son: Moncloa-Aravaca, Fuencarral-El Pardo, Moratalaz, Arganzuela y Centro. <br>
# - 1 coincidencia. <br>
#
#
# **A MAYOR NÚMERO DE HABITANTES POR VEHÍCULO EN EL DISTRITO, MEJOR CALIDAD DEL AIRE** <br>
# Esta hipótesis es **FALSA**.
# - Los Distritos que registran un **mayor Número de Habitantes / Número de Coches** son: Usera, Carabanchel, Puente de Vallecas, Latina y Villaverde. <br>
# - Los Distritos que registran una **menor Concentración de Dióxido de Nitrógeno (NO2)** son: Moncloa-Aravaca, Fuencarral-El Pardo, Moratalaz, Arganzuela y Centro. <br>
# - 0 coincidencias.
